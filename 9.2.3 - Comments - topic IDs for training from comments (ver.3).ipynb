# %% [markdown]
# ## Prepare grades for comments

# %%
import pandas as pd

# %%
path = '../other_dumps/comments'

# %%
# open the file where we'll add the final decision about comments
df_with_comments = pd.read_csv(f'{path}/VER3_all_comments_to_theories_with_scores.csv')
df_with_comments.head()
# Out:
#       id     status    thread  \
# 0   9403      fixed   comment
# 1   9408  won't fix   comment
# 2  15054      fixed  feedback
# 3  15115      fixed  feedback
# 4  15268      fixed   comment
#
#                                                 text                 time  \
# 0  "...to divide between two your friends"\r\nI t...  2019-06-08 20:14:45
# 1  It was not completely clear for me, how to con...  2019-06-08 20:32:26
# 2                           completly not understood  2019-07-09 11:11:43
# 3  A better explanation is needed with clear defi...  2019-07-09 17:34:21
# 4  >remember that 2^8 in decimal is 1000 0000 in ...  2019-07-10 16:03:41
#
#                              content_link block_name  enabled  abuses  likes  \
# 0  https://hyperskill.org/learn/step/5614       text        0       0      0
# 1  https://hyperskill.org/learn/step/5614       text        1       0      3
# 2  https://hyperskill.org/learn/step/5753       text        1       0      0
# 3  https://hyperskill.org/learn/step/5753       text        1       0      0
# 4  https://hyperskill.org/learn/step/5753       text        0       0      1
#
#    ...  anon_user_id  area step_id  topic_id  \
# 0  ...            45  math    5614     370.0
# 1  ...            45  math    5614     370.0
# 2  ...           105  math    5753     385.0
# 3  ...           109  math    5753     385.0
# 4  ...           122  math    5753     385.0
#
#                                  lemmatized_comments count_bad  \
# 0  " ... to divide between two your friend " \r\n...         0
# 1  it be not completely clear for I , how to conv...         1
# 2                           completly not understand         1
# 3  a well explanation be need with clear definiti...         2
# 4  > remember that 2 ^ 8 in decimal be 1000 0000 ...         0
#
#    TextBlobPolarity  FlairPolarity  VaderPolarity  comment_grades
# 0          0.000000       0.817580         0.7351             0.5
# 1          0.065278      -0.999997         0.6766             0.0
# 2          0.000000      -0.999818         0.0000             0.0
# 3          0.300000       0.765204         0.6705             0.0
# 4          0.000000      -0.999927         0.0258             0.5
#
# [5 rows x 21 columns]

# %%
print(df_with_comments.shape[0])
print(df_with_comments[df_with_comments.count_bad > 0].shape[0])
# Out:
# 23905
# 9077

# %%
df_with_polarities = pd.read_csv(f'{path}/all_comments_to_theories_with_3_polarities.csv')

# %%
print(df_with_polarities.shape[0])
print(df_with_comments.shape[0])
# Out:
# 23905
# 23905

# %%
# add polarities to the file with counts of bad words
df_with_comments['TextBlobPolarity'] = df_with_polarities.TextBlobPolarity
df_with_comments['FlairPolarity'] = df_with_polarities.FlairPolarity
df_with_comments['VaderPolarity'] = df_with_polarities.VaderPolarity
df_with_comments.head()
# Out:
#       id     status    thread  \
# 0   9403      fixed   comment
# 1   9408  won't fix   comment
# 2  15054      fixed  feedback
# 3  15115      fixed  feedback
# 4  15268      fixed   comment
#
#                                                 text                 time  \
# 0  "...to divide between two your friends"\r\nI t...  2019-06-08 20:14:45
# 1  It was not completely clear for me, how to con...  2019-06-08 20:32:26
# 2                           completly not understood  2019-07-09 11:11:43
# 3  A better explanation is needed with clear defi...  2019-07-09 17:34:21
# 4  >remember that 2^8 in decimal is 1000 0000 in ...  2019-07-10 16:03:41
#
#                              content_link block_name  enabled  abuses  likes  \
# 0  https://hyperskill.org/learn/step/5614       text        0       0      0
# 1  https://hyperskill.org/learn/step/5614       text        1       0      3
# 2  https://hyperskill.org/learn/step/5753       text        1       0      0
# 3  https://hyperskill.org/learn/step/5753       text        1       0      0
# 4  https://hyperskill.org/learn/step/5753       text        0       0      1
#
#    ...  anon_user_id  area step_id  topic_id  \
# 0  ...            45  math    5614     370.0
# 1  ...            45  math    5614     370.0
# 2  ...           105  math    5753     385.0
# 3  ...           109  math    5753     385.0
# 4  ...           122  math    5753     385.0
#
#                                  lemmatized_comments count_bad  \
# 0  " ... to divide between two your friend " \r\n...         0
# 1  it be not completely clear for I , how to conv...         1
# 2                           completly not understand         1
# 3  a well explanation be need with clear definiti...         2
# 4  > remember that 2 ^ 8 in decimal be 1000 0000 ...         0
#
#    TextBlobPolarity  FlairPolarity  VaderPolarity  comment_grades
# 0          0.000000       0.817580         0.7351             0.5
# 1          0.065278      -0.999997         0.6766             0.0
# 2          0.000000      -0.999818         0.0000             0.0
# 3          0.300000       0.765204         0.6705             0.0
# 4          0.000000      -0.999927         0.0258             0.5
#
# [5 rows x 21 columns]

# %%
def get_neg_score_from_three(blob, flair, vader, blob_thrshld=0.5, flair_thrshld=0.75, vader_thrshld=0.5):
    """
    Comment has >= 2 negative scores --> negative.
    Otherwise -- neutral.
    """
    list_less_thrshld = [el <= -thrshld for el, thrshld in zip([blob, flair, vader], 
                                                               [blob_thrshld, flair_thrshld, vader_thrshld])]
    if sum(list_less_thrshld) >= 2:
        return -1
    else:
        return 0

# %%
grades = []

for i, row in df_with_comments.iterrows():
    if row.count_bad == 0:  # if there are no suspicious words in the comment, we mark it separately
        grades.append(0.5)
        continue
    
    blob = row.TextBlobPolarity
    flair = row.FlairPolarity
    vader = row.VaderPolarity
    
    common_decision = get_neg_score_from_three(blob, flair, vader)
    grades.append(common_decision)
    
df_with_comments['comment_grades'] = grades
df_with_comments.comment_grades.hist()
# Out:
# <AxesSubplot:>

# %%
print(df_with_comments[df_with_comments.comment_grades == -1].shape[0])  # 'bad' comments
# Out:
# 753

# %%
print(df_with_comments[df_with_comments.comment_grades == 0].shape[0])  # all other comments
# Out:
# 8324

# %%
print(df_with_comments[df_with_comments.comment_grades == 0.5].shape[0])  # comments without trigger words
# Out:
# 14828

# %%
df_with_comments.to_csv(f'{path}/VER3_all_comments_to_theories_with_scores.csv', index=False)

# %% [markdown]
# ## Get topics' division from comments' grades

# %% [markdown]
# Topics that have >=3 or 2 negative comments – bad topics. Everything else – good topics.

# %%
def count_good_and_bad_comments_per_each_topic(df):
    """
    We need to store IDs of comments, to be able to check the number of their reactions later.
    """
    bad_comments_count_for_topics = dict()
    good_comments_count_for_topics = dict()

    for i, row in df.iterrows():
        status = row['status']
        comment_grade = row['comment_grades']
        topic_id = row['topic_id']

        # add the bad comments count
        if topic_id in bad_comments_count_for_topics:
            if comment_grade == -1 and status != 'fixed':
                bad_comments_count_for_topics[topic_id].append(row.id)
            else:
                pass  # topic is in the dict but this comment is not bad so we don't add it

        else:
            if comment_grade == -1 and status != 'fixed':
                bad_comments_count_for_topics[topic_id] = [row.id]  # this is the first comment for topic and it's bad
            else:
                bad_comments_count_for_topics[topic_id] = []  # this is the first comment for topic and it's not bad

        # now add the good comments count
        if topic_id in good_comments_count_for_topics:
            if comment_grade == 1:
                good_comments_count_for_topics[topic_id].append(row.id)
            else:
                pass 
        else:
            if comment_grade == 1:
                good_comments_count_for_topics[topic_id] = [row.id]  
            else:
                good_comments_count_for_topics[topic_id] = []
                
    return bad_comments_count_for_topics, good_comments_count_for_topics

# %%
bad_comments_count_for_topics, good_comments_count_for_topics = count_good_and_bad_comments_per_each_topic(df_with_comments)

# %%
bad_comments_count_for_topics[362]
# Out:
# [193128, 1579354]

# %%
def divide_into_bad_and_rest(bad_comments_count_for_topics, threshold):
    """
    For each topic, if it has >=threshold bad comments -- it's bad. Otherwise it's 'the rest'.
    """
    final_bad_topics = []
    final_rest_topics = []

    for topic_id in bad_comments_count_for_topics:
        bad_num = len(bad_comments_count_for_topics[topic_id])

        if bad_num >= threshold:
            final_bad_topics.append(topic_id)
        else:
            final_rest_topics.append(topic_id)
            
    return final_bad_topics, final_rest_topics

# %%
final_bad_topics_3, final_rest_topics_3 = divide_into_bad_and_rest(bad_comments_count_for_topics, threshold=3)

# %%
print('good dataset', len(final_rest_topics_3))
print('bad dataset', len(final_bad_topics_3))
# Out:
# good dataset 1031
# bad dataset 89

# %%
final_bad_topics_2, final_rest_topics_2 = divide_into_bad_and_rest(bad_comments_count_for_topics, threshold=2)

# %%
print('good dataset', len(final_rest_topics_2))
print('bad dataset', len(final_bad_topics_2))
# Out:
# good dataset 958
# bad dataset 162

# %% [markdown]
# ## Check the division of the topics with high likes and extend the corpus

# %%
import pickle

# %%
import pandas as pd

# %%
step_id_topic_id_mapping = pickle.load(open('step_id_topic_id_mapping.pkl', 'br'))

# %%
file = '../topics_with_statistics/topics_3_months_with_statistics_and_scores.csv'

# %%
topic_statistics = pd.read_csv(file)

# %%
# df with topcis where we can trust likes (with >20 evaluations)
more_likes = topic_statistics[topic_statistics.last_3_month_likes_count > 20]
very_good_topics = more_likes[more_likes.last_3_month_avg_like > 1.85]
good_like_steps = [row['step_id'] for i, row in very_good_topics.iterrows()]
good_like_topics = set([step_id_topic_id_mapping[step_id] for step_id in good_like_steps])

# %%
# even here we get some intersection with topics with high likes
intersected_good_like_bad_comments_3 = good_like_topics.intersection(final_bad_topics_3)
print(len(intersected_good_like_bad_comments_3))
# Out:
# 5

# %%
# let's look at comments to these 5 topics

for el in intersected_good_like_bad_comments_3:
    print('#####' * 8 + str(el) + '####' * 8)
    comments_for_this_topic = df_with_comments[df_with_comments.topic_id == el]
    for com in comments_for_this_topic.text.values:
        if len(com) < 10000:
            print(com)
            print('<-------------->')
    print()
# Out:
# ########################################673.0################################
# Typo -  Once you download the executable file for Windows on an archive for Linux
# Must be -  Once you download the executable file for Windows or an archive for Linux
# <-------------->
# How do I learn with no images showing up?
# <-------------->
# I don't know if the website has changed, but using your request 'https://regres.in/api/users/2' gives me a VERY different result in Postman. I'm basically just seeing a JSON version of the DOM for the website.
# <-------------->
# You're trying to get regres.in but examples in the topic use reqres.in
# <-------------->
# Argh! A subtle but important detail! Thanks!!
# <-------------->
# very fascinating. Please add some more explanation about what reqres and postman really are/do. The examples are quite nice but it would be better to explain a bit more in detail about reqres!
# <-------------->
# The name of reqres server is formed from words REQuest and RESponse, so you can send requests to it and get responses back. Its only purpose is to provide some test data with the REST API.
#
# Postman is a client to make requests to any server you like.
# <-------------->
# Ok.
# <-------------->
# There is Advanced REST Client Chrome extension....
# <-------------->
# Make sure to change your settings in POSTMAN according to the images in the theory.
# <-------------->
# by adding some more examples of API
# <-------------->
# In Section §3 POST requests: instructions are unclear. Do I have to change the endpoint to https://reqres.in/api/register ?
# <-------------->
# Give PostWoman a try as an alternative to PostMan. No Download needed.
# <-------------->
# I don't need a postman and never will. Why do you want me to register for a service I don't need? Why would I need to download something to my computer when I'm just studying simple queries? There are many other services for sending requests to the server. Many of them do not require registration and download, many of them work as a browser plugin. Then you test my skills in using the postman service, without which I cannot continue my progress. WHY? Is this an industry standard? Is it strictly necessary for writing a REST service? Does he have no alternatives?
#
# Do you really think that I strictly need a postman to become a Java programmer? It is so necessary that I cannot continue my training until I tell you which buttons must be pressed in this application in order to do something?
#
# I am extremely disappointed. This is just silly.
# <-------------->
# This should be mentioned in the lesson. No download is a big plus for simple experiments.
# <-------------->
# Postman has very nice intro (6 short videos):
# https://www.youtube.com/playlist?list=PLM-7VG-sgbtAgGq_pef5y_ruIUBPpUgNJ
# <-------------->
# In POST requests, second paragraph, the description does not match the picture.  You must follow the picture to get the correct results.
# <-------------->
# §3 for POST method, it is not mentioned in the text to change url to "https://reqres.in/api/register". For clarity ;)
# <-------------->
# It has been rebranded: https://hoppscotch.io/
# <-------------->
# I read everything but I could not understand what this is helpful for and why do I need it.
# <-------------->
# The post part is beyond unclear, I would murder the person who wrote this if I could do it over the internet.
# Since I cant ill just get googling.
# <-------------->
# I would murder the person who wrote this if I could do it over the internet.
# Since I cant ill get googling. cheerios bros.
# <-------------->
# How to implement this in our project "Hypercar Service Center" would be great addition to our learning experience, not sure is it meant to be used or it's just a general knowledge.
# <-------------->
# in the POST request i followed exactly the instruction but in the Body section (x-www-form-urlencoded) it doesn`t show any email data we get in the previous GET request (tracey.ramos@reqres.in)
# <-------------->
# reqres.in has updated some methods
# <-------------->
# I think this is one of the most interesting and most important subjects here. Especially when you are a data analysis enthusiast.
# <-------------->
# why?
# <-------------->
# why not something like httpie? much simpler
# <-------------->
# I followed the steps from the theory section and I got an error on the POST request
# {
#     "error": "Missing email or username"
# }
# I used the email shown in the example and also another email that I got from the previous GET step and the same error appeared. What's the issue?
# <-------------->
# Use request body instead of query parameters to send login and password. It worked for me.
# <-------------->
# The 'raw' option doesn't work for me either ("Missing email or username"), but 'x-www-form-urlencoded' succeeds
# <-------------->
# Please make sure you have 'JSON' selected in the drop-dow control from the right
# <-------------->
# The POST example cannot be reproduced with an anonymous postman account. The answer is always {"error": "Missing email or username"}
# <-------------->
# I would have preferred the explanation on how to use HTTP requests with IntelliJ/PyCharm.
# <-------------->
# You do not need to download Postman to try out the examples in this theory topic. I was able to work through all of them using the browser version of Postman.
# <-------------->
# some parts of text were not really understandable, dunno if i am just stupid or it is badly described
# exactly §3 POST requests, under image, i did not really understood what was talked about
# <-------------->
# After reading theory and practising. I asked my self, how can you get the token without manually copy/paste from Postman to IntelliJ IDEA? Uhm ...
# <-------------->
# post request as written gets an error.  also using patch is not previously introduced
# <-------------->
# quess I'm not the only one who gets their g and q the wrong way round.
# <-------------->
#
# ########################################232.0################################
# "otherwise, the it is false" -- an unnecessary article
# "Sometimes we even do need to declare a new variable" -- perhaps, "do not"?
# <-------------->
# Seems like there is a mistake.
# "Sometimes we even do NOT need to declare a new variable for storing a result."
# <-------------->
# Typo?
# Noe that the situation when they both are executed is impossible.
# <-------------->
# "Unlike other languages (such as Java, Python, C#)..."
# I find it very interesting that JetBrains left out C/C++...
# <-------------->
# The chess questions are absolutely horrid, especially if you're not a chess player. I hated them so much, I feel like I'm done with this stuff if this is how the course continues.
# <-------------->
# A mistake: in 1§ last block of code:
# val b = ... // it is true oF false (Boolean)
# <-------------->
# "This code tests the value is divided by 2 and, if it is true, tests the value is divided by 3. If it is also true, it means the value is divided by 6."
#
# Replace the words divided with divisible.
# <-------------->
# Does this mean there is no ternary in Kotlin? And can I inline multiple else-ifs, like val something = if expr0 res0 else if expr1 res1 else if expr2 res2 [...] else if expr[n-1] res[n-1] else res[n] ?
# <-------------->
# Yes, there is no ternary operator in Kotlin.
# <-------------->
# I doubt they meant anything by that. After all, they can't name every single programming language, since there are hundreds, if not thousands.
# <-------------->
# "Sometimes we even do NOT need to declare a new variable for storing a result. In this example, we compare two numbers and print the text information passing it to a function."
#
# The code that follows shows the three branches printing some text depending on the comparison of the values, but it doesn't seem to show anything passing to a function.  Or am I missing something?
# <-------------->
# Very different to python indeed
# <-------------->
# It has a typo in the "computer cost" part. In the code, it says "else if (dollars < 100_000)" but in the text it says "else if (dollars < 10_000)"
# <-------------->
# Instead of assigning the result of the if/else conditional statement to a variable and then using println() to print the variable, the result is passed to the println() function directly by including it in the parenthesis.
# <-------------->
# The codeblocks both ended with the value to be returned:
#
# val max = if (a > b) {
#     println("Choose a")
#     a       //  <=== Returns a as a result to be assigned to max
# } else {
#     println("Choose b")
#     b       //  <=== Returns b as a result to be assigned to max
# }
# <-------------->
# Perhaps using colors to differentiate nested codes would be useful.
# <-------------->
# ’If all the bodies contain only a single statement, you can skip braces:’
#
# What does "single statement" mean here? is it a natural English statement or a programming statement?
#
# When does a conditional's body tend to have single-line property?
#
# Thanks for any explanation, friends.
# <-------------->
# that function is println()
# <-------------->
# I did not like ternaries anyway
# <-------------->
# It is programming statement, like this example:
#
# if (1 == 1) {
#    println("this if")
#    println("has multiple statements (commands) ")
#    println("and need braces")
# }
#
# if (2==2) println("But this has only one statement. You don't need braces")
# <-------------->
# Thank you very much for your wonderful explanation.
# <-------------->
# Article touches topic of nesting if's but doesn't touch return-early.
# <-------------->
# At least write the difference of the else if expression, not just the syntax
# <-------------->
# get ready to learn irrelevant shit in these practice question.... waste of fucking time #teamtreehouse is sooo much better... i didnt come here to learn about chess stupid mf's
# <-------------->
# Would it make sense to introduce the 'when' statement here? I really prefer it compared to the multiple if / else if syntax.
# <-------------->
# In my opinion, it is bad practice to do if-else logic inside a print statement.
# But in the practice exercises (and theory) about this subject you will see code structured as
# "println(if ... ... else ... ...)"
#
# If it was me, I would tell people to do the printing inside the body (aka inside the {} brackets)
# So it can't interfere with the code handeling the if-else logic.
#
# If, besides having to write print less often, there are compiler/optimization reasons for doing it inside the print statement, feel free to enlighten us all.
# <-------------->
# I have no idea how the syntax is supposed to work here. I'm trying to say that if(year / 4 && !(year / 100)) etc... but, that's a boolean, how the hell do you separate these two equations? A comma? The examples they give us are no simple I have to painfully scour the internet, hints, to get some of these answers right. They make you writhe to solve each problem. Which is good to an extent, but I waste so so much time on these problems lol.
# <-------------->
# I came up with a cool idea... !/ which is NOT divisble by, except that probably doesn't exist. I have no idea how to join two conditions under the same if.
# <-------------->
# Finally I could understand it! I'm so glad \o/
# <-------------->
#
# ########################################585.0################################
# I'm sorry I have to say this: I got the opposite impression during reading this text. The example looks more like a subject for a loop, I think! Maybe a tree-based problem would be better?
# <-------------->
# maybe you guys could point our how to solve matricx determinants using a recursion method. not the math behind it, just use it as an example, if that makes any sense?
# <-------------->
# the 'start' parameter confused me until I realized the initial / outermost value is always zero.  Before that, I thought you were writing a function that had an arbitrary start.  Adding a phrase like 'initially, zero' after 'from where to start the search' in the paragraph beginning 'Our recursive function' would have helped me.
# <-------------->
# A question as I'm new to this:
# Wouldn't it be better if we modify the elif statement like this:
#
#     elif i == len(word) - 1:
#         if (previous_char in vowels) and (word[0] != "'"):
#             return i
#         return -1
#
# considering that the last character would be diacritic if the first character is not a quotation mark. Or am I missing something?
# <-------------->
# A loop would be much better for given example!
# <-------------->
# Loops would be better for given example.
# <-------------->
# This example is more confusing than helpful for demonstrating the power of recursion imo...
# <-------------->
# 1) Theory should be clarified and fixed.
#
# 2) How one can claim that eating candy is recursive but not an example of a loop? You can fix it with each  candy should be eaten and its package should be thrown away. So, one can eat and throw away package is an example of loop but opening all packages and then eating when all candies opened and throwing packages away is recursive.
#
# 3) Factorial example should be fixed as like:
#
# 5! = 5 * 4!  = 5 * 4 * 3! = 5 * 4 * 3 * 2! = 5 * 4 * 3 * 2 * 1
#
# this is more understandable for the topic.
#
# 4) This has not seen:
#
# So, as you have seen, this task can be quite easily solved with the help of recursion, and solving it using loops would be much less natural.
# <-------------->
# In order to define recursion, we must first define recursion.
# <-------------->
# comparison with same problem solved using loops would make a much stronger case for recursion
# <-------------->
# According to the complains of follow comments, maybe should consider using "Towers of Hanoi" to show the power of recursion.
# <-------------->
# This one did not help in understanding recursion at all
# <-------------->
# I agree!
# <-------------->
# Agree WY
# <-------------->
# the problem recursion is solving seems a little forced
# <-------------->
# The example is hard to understand.
# <-------------->
# Honestly, I think everyone would be better off if they just skipped reading this one.
# <-------------->
# I can't believe how well-written this piece is! And I'm not joking, like seriously! 💕
# <-------------->
# I think the solution to this particular problem looks more concise and intuitive with a for-loop. But the rest of the theory on recursion is clear, thanks!
# <-------------->
# "#  the apostrophe is the last symbol, doesn't meet the condition"
# Who wrote this? What about Portuguese for "hello": Olá (Ola') ?
# <-------------->
# Well, I do not see the benefit over using the for loop. If that was compared and explained maybe I would find the recursion useful. So far while and for sounds like better option as it is easier to write. Or is the recursion at least quicker? I do not know, can you please explain more in details?
# <-------------->
# Well, I do not see the benefit over using the for loop. If loops and recursions were compared and explained for differences maybe I would find the recursion useful. So far while and for sounds like better option as it is easier to write. Or is the recursion at least quicker? I do not know, can you please explain more in details? MUch less natural does not really help when the loop is currently more natural while learning Python...
# <-------------->
# Recursion golden era is gone - it was times when "for i=0; i<10; i=i+1"  was the only way to loop in most of languages, and using function was a top standard like using objects today. There was not much other options and people did magic using recursion. Some of them are teaching now forgetting that world of codding changed dramatically.
# <-------------->
# wouldn't something like this be easier to read or write?
#
# def find_apostrophe(word, start=0):
#
#     i = word.find("'", start)
#
#     if i == -1:
#         return -1
#     elif i == 0 or i == len(word) - 1:
#         return -1
#     else:
#         previous_element = word[i - 1]
#         if previous_element in vowels:
#             return i
#         return -1
# <-------------->
# wouldn't something like this be much easier to write and read while doing same thing?
#
# def find_apostrophe(word, start=0):
#
#     i = word.find("'", start)
#
#     if word[i - 1] in vowels:
#         return i
#     return -1
# <-------------->
# wouldn't something like this be much easier to write and read while doing same thing?
# def find_apostrophe_without(word, start=0):
#     i = word.find("'", start)
#     if word[i - 1] in vowels:
#         return i
#     return -1
# <-------------->
# I understood the concept of recursion with this example. However, It didn't become clear to me how it is better than using a loop. I think a precise comparison of the two alternative solutions (recursion and loop) with pointing out the strengths of recursion might have helped here.
# <-------------->
# I don't know. If you say it saves programmers time when writing the code, it definitely does help others trying to understand it. My head is about to explode every time I am looking at a recursive function...
# <-------------->
# Well, if you say it saves programmer's time when writing it, it definitely does NOT help others trying to understand it. My head is about to explode every time I am looking at a recursive function...
# <-------------->
# Not really obvious why loop would be worse. It seems natural to loop from 1 to -1, ignoring first and last characters.
# <-------------->
# missing all the edge cases.
# <-------------->
# def find_apostrophe(word, start):
#     for i, character in enumerate(word[start:-1], start):
#         if character == "'":
#             if i == 0:
#                 continue
#             else:
#                 if word[i - 1] in vowels:
#                     return i
#     else:
#         return -1
# <-------------->
# Hi! Don't forget the fact that recursion is a must-know topic about mathematical functions (a basic topic), and programming derives from Maths. It just seems weird if it's the first time you see it, but it's a very powerful method along with loops. Both have their issues depending on the implementation.
# In a loop, it could be straightforward knowing what to do in each step (and they are better in imperative languages), but recursion is better for a mathematical description of what's going on and how the problem is solved (it should be much faster in functional languages)
# <-------------->
# You still have to initialize a variable with the base case/accumulator and to specify a start, a stop and an increment with Python for loops, am I wrong? But not even at the same line, so
#
# >IDK how to define fxs in Java<
# int n = 1;
# for (int i=5; i > 0; i--) {
#     n = n * i;
# }
#
# VS
#
# def loop_fact(n):
#     t = 1
#     for i in range(1, n + 1):
#         t *= i
#     return t  # faster
#
# VS
#
# def rec_fact(n):
#     return 1 if not n else n * rec_fact(n - 1)  # concise
#
# Now getting fibonacci by index would be
#
# def rec_fibo(n):
#     return n if n < 2 else fibo(n - 1) + fibo(n - 2)
#
# VS
#
# def loop_fib(n):
#     a, b = 1, 1
#     for n in range(n - 1):
#          a, b = b, a + b
#     retrun a
#
# Performance will always depend on the implementation, but recursion gets easier -compared with loops- the more complex the problem gets.
# <-------------->
# You still have to initialize a variable with the base case/accumulator and to specify a start, a stop, and an increment with Python for loops, am I wrong? But not even at the same line, so
#
# >IDK how to define fxs in Java<
# int n = 1;
#     for (int i=5; i > 0; i--) {
#         n *= i;
#     }
#
# VS
#
# def loop_fact(n):
#     t = 1
#     for i in range(1, n + 1):
#         t *= i
#     return t  # faster
#
# VS
#
# def rec_fact(n):
#     return 1 if not n else n * rec_fact(n - 1)  # concise
#
# Now getting Fibonacci by the index would be
#
# def rec_fibo(n):
#     return n if n < 2 else fibo(n - 1) + fibo(n - 2)
#
# VS
#
# def loop_fib(n):
#     a, b = 1, 1
#     for n in range(n - 1):
#          a, b = b, a + b
#     retrun a
#
# The performance will always depend on the implementation, but recursion gets easier -compared with loops- the more complex the problem gets.
# <-------------->
# This part of the example is not very clear:
#   previous_char = word[i - 1]
#         if previous_char in vowels:
#             return i
# <-------------->
# Solving this example with loops WOULD be much natural.
# <-------------->
# There is a max recursion depth in python.
# <-------------->
# Second example is not clear. You didn't convince me, that recursion is better than a loop here.
# <-------------->
# You would then need to take into account that the first char in the index is not an apostrophe, and that the next char from the apostrophe in Ola' is not another apostrophe.
# <-------------->
# Still fairly confused with recursion, but like with everything else, practice makes perfect.
# <-------------->
# 999 on my machine ;)
# <-------------->
# In 80s with computer RAM counted in megabytes each character saved in code was worth to save ;)
# <-------------->
# The second paragraph should not exist.
# <-------------->
# The second paragraph should not exist.
# <-------------->
# Ahem, "When not to write useless paragraphs"...
# <-------------->
# When not to loop? -> When not to write useless and terrible paragraphs...
# It's a very wrong decision, to try to explain a concept (BTW, not that complex one) with a convoluted, complex and questionable example.
# <-------------->
# One of the best practically applied lesson. I had a task for the job application test on Test Gorilla, and for that time I wasn't  aware of function recursion, that was the key idea in solution, so I failed that part of the test.
# <-------------->
# Do You really think recursion for finding vowel+' is more natural?
# I do not.
#
# Iterating over string using length from 1 to n-1 seems more natural to me.
# Not even taking to account resources needed.
# <-------------->
# The last example is quite confusing
# <-------------->
# In the previous topic ('Recursion basics') they were telling us that factorial basic case should be x==1, now it's x==0! Why so?
# <-------------->
# TYPO:
# Here's an important thing: a recursive function has to terminate to be used in a program, otherwise it can lead to an infinite loop, and the program will continue to execute forever.
#
# HAS TO BE TERMINATED
# <-------------->
# I want to clarify the example below:
# def recursive_factorial(n):
#     # Base case
#     if n == 0:
#         return 1
#     # Recursive case
#     else:
#         return n * recursive_factorial(n - 1)
#
# the line :
# return n * recursive_factorial(n - 1)
#
# works as per below:
# let's take n=4 :
# recursive_factorial(n)
#
# in this case we will have:
# 4! = 4 * 3! = 4 * 3 * 2!  = 4 * 3 * 2 * 1! = 4 * 3 * 2 * 1 *0!  as 0! = 1,
# 4! = 4 * 3 * 2 * 1 * 1 = 24
# result will be 24, so it's not really clear from the formula that our n * n -1  is not 4! = 4 * 3, but
# 4! = 4 * 3 * 2 * 1 *1
# <-------------->
# -1 is a default return if nothing found
# <-------------->
# Sorry, I understand this is just an example to make us understand but as an Italian I don't understand why would you exclude words that have an apostrophe as a last character just because it could be a quotation mark. There are so many Italian words that terminate with diacritics, it would be sufficient to check if the next character is also a quotation mark.
# <-------------->
# I don't get the Italian exam.
# <-------------->
# Very bad example for recursion, it's more for loop
# <-------------->
# I think this was done for simplicity
# This function was just an example of how to work with recursion, no need to complicate it)
# <-------------->
# It's just about another step.
# 0! = 1
# 1! = 1
# So it doesn't matter what is the basic case: 0! or 1!
# <-------------->
# i dont understand about this sentence below :
# If we go back to the structure of a recursive function, it means that even if the base case isn't defined, you won't be able to execute your program forever. When the maximum recursion depth is exceeded, you'll get an error.
# <-------------->
# Ah yes, the recursion - every beginner's programmer nightmare ;) fear not, you will get it, practice makes perfect!
# <-------------->
# This code will run indefinitely:
# while True:
#     pass
#
# but this function will call itself only x times, where x is "maximum recursion depth" defined in python:
# def func():
#    func()
# <-------------->
# What is wrong with equality signs in the second paragraph??
# At first, I was afraid that I'm seeing doubles, but then I realized that it is just sign rendering. Is it some kind of mathematical
# convention to make non-mathematicians suffer?
# <-------------->
#
# ########################################429.0################################
# input() and range() are not methods, they don't associated with objects, they a built-in functions, as described in docs.
# <-------------->
# Unclear how you can use ocean as a variable in the for loop when ocean is undefined.
# <-------------->
# It is worth saying how the range() function works
# <-------------->
# You never explained anything about the 'variable' in the for loot statement in terms of how it works
# <-------------->
# bad explanation!!!!!!!
# <-------------->
# bad explanation!!!!!!!
# <-------------->
# I didn't understand how you were using for loops with words like ocean without ever assigning a variable to ocean vs oceans.
# <-------------->
# Give examples of definite and indefinite iteration, either in the intro or later in the theory, otherwise introducing the terms in the intro is redundant and confusing.
# <-------------->
# Confusing
# <-------------->
# How is the variable defined? How does it know what in the oceans list is an ocean? How is "i" defined in the for loop? How is it connected to the input?
# <-------------->
# very interested range() !!
# <-------------->
# Terribly explained chapter. I'm so confused after reading this. In the following example:
# for variable in iterable:
#     statement
# and the subsequent examples, where does the variable come from? Do I define it earlier?
# What do I do if I want to iterate only the second half of a list?
# For the first time in reading chapters on the lessons here, I have literally 0 clarity about what's going on here. Seems like the author of this lesson has taken it for granted that I know these things such as the origin of the variable in the syntax. Well, I don't, which is why I'm here.
# In the range() function second example, can I do range(5, 29, 5)? instead of the second argument being 30? Will I get an error?
# Should there have been examples of indefinite iterations? How do I add a perpetually true condition?
# Maybe I'm nitpicking, but this one has left me very confused.
# <-------------->
# for lesson in hyperskill:
#     learn(lesson)
# <-------------->
# To memorize why the last number in a range is not printed:
# Remeber: Arrays indices start with 0.
# And: Range indicates the number of items to print starting with 0.
# range(5) means therefore: 0, 1, 2, 3, 4 which obviously are 5 items
# <-------------->
# It's not clear how the statement "for name in names" in section 5 works; you've not specified that either of the inputs are a "name" and I'm very confused on how to actually use it.
# <-------------->
# More details and examples of how we can use range to control the number of iterations
# <-------------->
# because it was bad
# <-------------->
# the theory doesn't fully prepare for the tasks
# <-------------->
# Open the way to the astral doors, then spin into a whirling infinity of light
# <-------------->
# for i in range(1, 5):
#    for i in range (3, 5):
#           print (i)
#
# my supposed answer is : 3
#                                             4
# but the answer is : 3
#                                  4
#                                  3
#                                  4
#                                  3
#                                  4
#                                  3
#                                  4
#
# How to understand it? Thanks!
# <-------------->
# I think the 3rd and 4th paragraph should change their place, the range should come first and be explained then should be given example in the Input data processing section.
# <-------------->
# It's just hard to understand for me
# <-------------->
# You basically asked it to loop (1, 5) (stops at 4 not 5)
#
# The nested part is asking to start at 3 and end at 5 so 3, 4 , NOT 5 is printed) for every range in your outer range.
#
# So it goes:
# Outer Range | Nested Range
#    loop 1 | Print 3, 4 ( not 5)
#    loop 2 | Print 3, 4
#    loop 3 | Print 3, 4
#    loop 4 | Print 3, 4
# *Stop here, because the outer range range is (1, 5)
#
# So it goes starts its first loop at 1, and prints 3 and 4 cause it stops at 5, then repeats the loop 3 more times.
# <-------------->
# in §4 the second code block shouldnt declare the variable i but should use "_" as introduced just before
# <-------------->
# `for name in names:
#     for surname in surnames:` should be
# `for surname in surnames:
#     for name in names:`
# <-------------->
# What do you mean "The TYPE of inner and outer loops doesn't matter" in the Nested loop section?
# <-------------->
# Why does it loop 4 times?
# <-------------->
# Here important to know, that range function keeps it's state.
# On every loop cycle variable i receives the current state of range function and this state is incremented by 1 (until reach the end).
# So range function actually don't care about current value of variable i, it has it's own counter inside.
# <-------------->
# It loops 4 times because range(1,5) means 4 elements. So for each of the 4 elements in the first loop (outer loop) it prints elements 3 and 4 (inner loop).
#
# iteration 1 done in outer for loop:
# i=1
#     iteration 1 done in inner for loop:
#     print(3)
#
#     iteration 1 done in inner for loop:
#     print(4)
#
# iteration 2 done in outer for loop:
# i=2
#     iteration 2 done in inner for loop:
#     print(3)
#     iteration 2 done in inner for loop:
#     print(4)
# <-------------->
# If you're not going to use the counter variable in your loop, you can show it by replacing its name with an underscore symbol:
#
# for _ in range(100):
#     do_smth()
# In the example above, we don't need the counter variable in any way, we simply use the loop to repeat do_smth() function a given amount of times.
#
# ---
#
# what is that number of times ? 100? for (0 to 99)?
# Does that use a default increment? If so, what is it's value ?
# <-------------->
# if you wanted only : 3, 4,
# you should've done:
#
# for i in range(1, 5):
#    if i in range (3, 5):
#           print (i)
# <-------------->
# Why not start the outer loop with 1?
# Outer loop: 1 2 3 4 5
# Inner loop: 3 4 5
# should be
#
# 1
# 3 4 5
# 2
# 3 4 5
# 3
# 3 4 5
# 4
# 3 4 5
# 5
# 3 4 5
#
# I am confused!
# <-------------->
# ok so for loop is indefinite iteration? since:
# a = [0]
# for elem in a:
#     a.append(elem + 1)
#     print(elem)
# # is an infinite loop
# <-------------->
# About the underscore iterator variable:
# You can name it _ ; but that's not the reason..underscore does not indicate an anonymous variable (like in Haskell) because underscore is a valid name in Python and you could use it the same way you'd use a or x or elem or i or whatever, inside or outside a for loop
# <-------------->
# for range(y) the length of the iterable will be x
# (^- here the initial and increment are 0 and 1 respectively by default)
# for range(x, y) the length of the iterable will be y - x
# (^- here the increment is 1 by default)
# for range(x, y, z) the length of the iterable will be (y - x) / z (rounded up)
#
# it's possible that z < 0 and it will go backwards:
# these combinations are the ones that make sense, but others won't raise errors:
# if z > 0, then x <= y
# if z < 0, then x >= y (notice the division wil be (negative / negative) -> positive, since z < 0 and y - x < 0)
#
# some tests:
#
# from math import ceil  # this function rounds up
# equiv = list()
# for x in range(-100, 100):
#      for y in range(-100, 100):
#              for z in [z for z in range(-100, 100) if z != 0]:
#                      if z > 0 and x <= y:
#                              equiv.append(len(range(x, y, z)) == ceil ((y - x) / z))
#                      if z < 0 and x >= y:
#                              equiv.append(len(range(x, y, z)) == ceil ((y - x) / z))
#
# print(False in equiv)  # outputs False, so they are all equals for these values
# <-------------->
# for range(y) the length of the iterable will be y
# (^- here the initial and increment are 0 and 1 respectively by default)
# for range(x, y) the length of the iterable will be y - x
# (^- here the increment is 1 by default)
# for range(x, y, z) the length of the iterable will be (y - x) / z (rounded up)
#
# it's possible that z < 0 and it will go backwards:
# these combinations are the ones that make sense, but others won't raise errors:
# if z > 0, then x <= y
# if z < 0, then x >= y (notice the division wil be (negative / negative) -> positive, since z < 0 and y - x < 0)
#
# some tests:
#
# from math import ceil  # this function rounds up
# equiv = list()
# for x in range(-100, 100):
#      for y in range(-100, 100):
#              for z in [z for z in range(-100, 100) if z != 0]:
#                      if z > 0 and x <= y:
#                              equiv.append(len(range(x, y, z)) == ceil ((y - x) / z))
#                      if z < 0 and x >= y:
#                              equiv.append(len(range(x, y, z)) == ceil ((y - x) / z))
#
# print(False in equiv)  # outputs False, so they are all equals for these values
# <-------------->
# for range(y) the length of the iterable will be y
# (^- here the initial and increment are 0 and 1 respectively by default)
# for range(x, y) the length of the iterable will be y - x
# (^- here the increment is 1 by default)
# for range(x, y, z) the length of the iterable will be (y - x) / z (rounded up)
#
# it's possible that z < 0 and it will go backwards:
# these combinations are the ones that make sense, but others won't raise errors (except z = 0):
# if z > 0, then x <= y
# if z < 0, then x >= y (notice the division wil be (negative / negative) -> positive, since z < 0 and y - x < 0)
#
# some tests:
#
# from math import ceil  # this function rounds up
# equiv = list()
# for x in range(-100, 100):
#      for y in range(-100, 100):
#              for z in [z for z in range(-100, 100) if z != 0]:
#                      if z > 0 and x <= y:
#                              equiv.append(len(range(x, y, z)) == ceil ((y - x) / z))
#                      if z < 0 and x >= y:
#                              equiv.append(len(range(x, y, z)) == ceil ((y - x) / z))
#
# print(False in equiv)  # outputs False, so they are all equals for these values
# <-------------->
# for range(y) the length of the iterable will be y
# (^- here the initial and increment are 0 and 1 respectively by default)
# for range(x, y) the length of the iterable will be y - x
# (^- here the increment is 1 by default)
# for range(x, y, z) the length of the iterable will be (y - x) / z (rounded up)
#
# it's possible that z < 0 and it will go backwards:
# these combinations are the ones that make sense, but others won't raise errors (except z = 0):
# if z > 0, then x <= y
# if z < 0, then x >= y (notice the division wil be (negative / negative) -> positive, since z < 0 and y - x < 0)
#
# some tests:
#
# from math import ceil  # this function rounds up
# equiv = list()
# for x in range(-100, 100):
#      for y in range(-100, 100):
#              for z in [z for z in range(-100, 100) if z != 0]:
#                      if z > 0 and x <= y or z < 0 and x >= y:
#                              equiv.append(len(range(x, y, z)) == ceil ((y - x) / z))
#
# print(False in equiv)  # outputs False, so they are all equals for these values
# <-------------->
# It's possible that z < 0 and it will go backwards.
# These combinations are the ones that make sense, but others won't raise errors (except z = 0):
# if z > 0, then x <= y
# if z < 0, then x >= y (notice the division wil be (negative / negative) -> positive, since z < 0 and y - x < 0)
#
# With those conditions:
# · range(y): the length of the iterable will be y
# (^- here the initial and increment are 0 and 1 respectively by default)
# · range(x, y): the length of the iterable will be y - x
# (^- here the increment is 1 by default)
# · range(x, y, z): the length of the iterable will be (y - x) / z (rounded up)
#
# Some tests:
#
# from math import ceil  # this function rounds up
# equiv = list()
# for x in range(-100, 100):
#      for y in range(-100, 100):
#              for z in [z for z in range(-100, 100) if z != 0]:
#                      if z > 0 and x <= y or z < 0 and x >= y:
#                              equiv.append(len(range(x, y, z)) == ceil ((y - x) / z))
#
# print(False in equiv)  # outputs False, so they are all equals for these values
# <-------------->
# It's possible that z < 0 and it will go backwards.
# These combinations are the ones that make sense, but others won't raise errors (except z = 0):
# if z > 0, then x <= y
# if z < 0, then x >= y (notice the division will be either Zero or (negative / negative) -> positive, since z < 0 and y - x <= 0)
#
# With those conditions:
# · range(y): the length of the iterable will be y
# (^- here the initial and increment are 0 and 1 respectively by default)
# · range(x, y): the length of the iterable will be y - x
# (^- here the increment is 1 by default)
# · range(x, y, z): the length of the iterable will be (y - x) / z (rounded up)
#
# Some tests:
#
# from math import ceil  # this function rounds up
# equiv = list()
# for x in range(-100, 100):
#      for y in range(-100, 100):
#              for z in [z for z in range(-100, 100) if z != 0]:
#                      if z > 0 and x <= y or z < 0 and x >= y:
#                              equiv.append(len(range(x, y, z)) == ceil ((y - x) / z))
#
# print(False in equiv)  # outputs False, so they are all equals for these values
# <-------------->
# It's possible that z < 0 and it will go backwards.
# These combinations are the ones that make sense, but others won't raise errors (except z = 0):
# if z > 0, then x <= y
# if z < 0, then x >= y (notice the division will be either Zero or (negative / negative) -> positive, since z < 0 and y - x <= 0)
#
# With those conditions:
# · range(y): the length of the iterable will be y
# (^- here the initial and increment are 0 and 1 respectively by default)
# · range(x, y): the length of the iterable will be y - x
# (^- here the increment is 1 by default)
# · range(x, y, z): the length of the iterable will be (y - x) / z (rounded up)
#
# Some tests:
#
# from math import ceil
# equiv = list()
# for x in range(-100, 100):
#     if x >= 0:
#         equiv.append(len(range(x)) == x)
#     for y in range(-100, 100):
#         if x <= y:
#             equiv.append(len(range(x, y)) == y - x)
#         for z in [z for z in range(-100, 100) if z != 0]:
#             if z > 0 and x <= y or z < 0 and x >= y:
#                 equiv.append(len(range(x, y, z)) == ceil((y - x) / z))
#
# print(False in equiv)  # outputs False, so they are all equals for these values
# <-------------->
# times = int(input('How many times should I say "Hello"?'))
# for i in range(times):
#     print('Hello!')
# shouldnt you use _ instead of i
# <-------------->
# There was not explained how to make calculations within loop
# <-------------->
# for i in range(2,5):
#       print(i)
# <-------------->
# I don't get it
# <-------------->
# I don't get it
# <-------------->
# required some more examples. to clearly understand the concepts.
# <-------------->
# Хотелось бы больше информации.
# <-------------->
# Glad I understand how nested for loops work because the explanation here is awful.
# <-------------->
# i like it,maybe i can review the feedback after am done with the exercises
# <-------------->
# "for _ in range(100):
#     do_smth()"
#
# I did not really understand this part of study, this code specify another thing regarding the code below?:
# or it can be using for another purpose, so what it is? I am really curious what is happening  :)
#
# "for i in range(100):
#     do_smth(i)"
# <-------------->
# for _ in range(5):
# 	do_smth()
#
# Here, it shows that you can omit loop's variable.
# As you can see, you invoke do_smth() without passing any arguments. The whole loop isn't using "_" anywhere.
# Mind that "_" is the common name for a not used variable.
#
# So, imagine that do_smth() looks like this:
# def do_smth(times=5):
# 	print('A' * times)
#
# Output is:
# AAAAA
# AAAAA
# AAAAA
# AAAAA
# AAAAA
#
# for i in range(5):
# 	do_smth(i)
#
# Here, you are passing a variable `i` to the function do_smth (values are 0, 1, 2, 3 and 4).
# Output is:
# 		# it's an empty string
# A
# AA
# AAA
# AAAA
# <-------------->
# Thank You, I see that "_" is a key variable for not using in the loop :)
# <-------------->
# for fruit in fruits:
#     print(fruit)
# <-------------->
# It is good, just 2 things:
# - The part with the "range(5, 45, 10):" should be explained a bit wider
# - The "times = int(input('How many times should I say "Hello"?'))" is a side topic but could be explained wider or supplemented with a link chosen by the staff, as it is an interesting concept too, that was not previously introduced.
# GJ tho', nice intro to For loops
# <-------------->
#
# ########################################121.0################################
# This lesson is terribly written and full of grammar mistakes. D:
# <-------------->
# Order of initialization:
# 1. Is there a superclass? initialize it first(using implicit super constructor or an empty one)
# 2. Static variable declaration and static initializers in the same order they appear in the class
# 3. Instance variables and instance initializers block in the same order they appear in the class
# 4. The class constructor
# <-------------->
# The example with "Before the constructor" output should actually include a no-arg constructor that prints "In the constructor" for clarity.
# <-------------->
# I did not fully understand, in which cases i would need it. If i want to initialize an array, why not in the constructor?
# <-------------->
# unclear
# <-------------->
# Not enough detail
# <-------------->
# I don't understand why you can't just write the code below and eliminate the need for static initialization blocks.
#
#     private static String stringField = getEmptyString();
#     private static Date dateField = new Date();
#
#     private static final String A_STRING_CONSTANT = "unknown";
#
#     private static String getEmptyString() {
#         return "empty";
#     }
# <-------------->
# They are just showing to us how we can use static blocks.
# <-------------->
# why this was ever introduced? and what kind of tasks we gonna solve with it in the cousre?
# <-------------->
# As to the why behind the theory:
#
# The static initializers are executed only once during runtime, specifically during loading of the class.  A use case for the static initialization block would be a JDBC  driver that registers itself to a DriverManager.
#
# The instance initializers are executed regardless of which constructor is used.  You can have a common shared initialization for the class without duplicating code in each constructor.
# <-------------->
# We could access to uninitialized default of value fields in the block above of initialization. So direct assignment operation hasn't priority over init-blocks. They just placed in order of presenting in source code and merge to one <init> or <clinit> method in bytecode.
#
# Example:
#
# public class Main {
#
#     static {
#         System.out.println(Main.staticField);
#     }
#
#     private static int staticField = 1;
#
#     static {
#         staticField = 42;
#         System.out.println(Main.staticField);
#     }
#
#     {
#         System.out.println(this.instanceField);
#     }
#
#     private int instanceField = 1;
#
#     {
#         instanceField = 42;
#         System.out.println(this.instanceField);
#     }
#
# }
# <-------------->
# Some information on why you would use this construction and in what cases would be much appreciated.
# <-------------->
# class Parent
# class Child extends Parent
#
# order:
# 1)Parent static block
# 2)Child static block
# 3)Parent initialization block
# 4)Parent Constructor
# 5)Child initialization block
# 6)Child Constructor
# <-------------->
# a table about the order of initialization of fields, methods and blocks is needed
# <-------------->
# Very important notes, I think those should be in the theory section.
# Many thanks!
# <-------------->
# I found the notes in the comment bellow very important to know, and I think it would be great if add to the theory.
# https://hyperskill.org/learn/step/3533#comment-520473
# <-------------->
# and notice that
# 2. Static variable declaration and static initializers in the same order they appear in the class called only once not per object
# <-------------->
# More examples where to use this topic!
# <-------------->
# не ясно, зачем это
#
# почему этот урок появился в стадии 1, которую я завершил давно?
# <-------------->
# Had to google about what benefits an "instance initialization block" offers.
# As I understand they are:
# - the block is invoked no matter how many constructors the class has
# - it can be used in anonymous classes where it's impossible to use a constructor
# <-------------->
# If we have super class and subclass then the order of initialization is:
# 1) Superclass' static block
# 2) Subclass' static block
# 3) Superclass' initialization block
# 4) Superclass' constructor
# 5) Subclass' initialization block
# 6) Subclass' constructor
# <-------------->
# A static initialization blocks is required when you need to write some instructions to initialize a static variable.
# If you can write directly something like "static Type myVariable = value", the block usage is useless.
# For clarity, don't use multiple static blocks and write it in the same location of your code than the static variables declaration.
#
# An instance initialization block performs common code for all instanciations, but hides the logic of each constructor. Its usage is discouraged when you can use constructors.
# <-------------->
# A static initialization block is required when you need to write some instructions to initialize a static variable.
# If you can write directly something like "static Type myVariable = value;", the block usage is useless.
# For clarity, don't use multiple static blocks and write it in the same location of your code than the static variables declaration.
#
# An instance initialization block performs common code for all instanciations, but hides the logic of each constructor. Its usage is discouraged when you can use constructors.
# <-------------->
# Does not offer any insight on why an instance initialization block is preferable, nor why multiple of them make sense.
# <-------------->
# Ok, let me ask which method should I choose in case for example I have to create bank account with account number.
# I have field private long accountNumber
# Should I create method private long createAccountNumber(); and invoke it in constructor this.accountNumber = createAccountNumber();
# or
# private long accountNumber;
# {
#      //  algorithm to creating account number
# }
# Which is considered as better practice?
# <-------------->
# I know that many people consider it bad practice to invoke instance methods from a constructor. That's because the object isn't completely created before the constructor finishes. So if you don't want to place too much code in your constructor, you can either use an initialization block or make something like:
# private static long initAccountNumber() { // method logic }
# Notice that it's static so it can be invoked from the constructor safely
# <-------------->
# Oh, sounds good.
# I oversighted this point.
# Thx
# <-------------->
# Conceptually I can understand the first bonus you mention, but I still find it odd that we don't use an init() method or something of the sort that's simply called in every constructor and provides better context.
#
# Did you find any examples and real-life use-cases?
# <-------------->
# OK, nice theory, but why would anyone want to write such constructions? What's the advantage? Why instance initialization blocks instead of modifying constructors? What happens when both are used?
# <-------------->
# Thanks for the information! Now I will read comments more often=)
# <-------------->
# I don't understand this statement "The instance initialization block is executed before any constructor of a class...The java compiler invokes the block as the first statement in the constructor, before other statements."
#
# Is the block executed before the constructor or in the constructor as the first statement?
# <-------------->
# Yes, static block is executed before constructor.
# <-------------->
# Then which block, according to the theory is invoked "as the first statement in the constructor, before other statements."?
# <-------------->
# Code in static or initialization blocks are invoked first.
# When you create object, constructor invokes first:
# static {
#    //code
# }
#
# second:
#
# {
#    //code
# }
#
# third: code in constructor
# <-------------->
# Code in static or initialization blocks are executed first.
# When you create object, your code will be executed in this order:
#
# static {
#    //code
# }
#
# {
#    //code
# }
#
# code in constructor
#
# Your question was "Is the block executed before the constructor or in the constructor as the first statement?"
#
# Answer is, when you create object by using keyword "new" you invoke constructor of the class, then code in initialization blocs are executed, then code in constructor is executed.
# <-------------->

# %%
585.0

# %% [markdown]
# But actually it's ok!
#
# * First topic 673 could actually use some improvement!
# * Second topic 232 too!
# * Third topic 585 too!
# * Fourth topic 429 too!
# * Fifth topic 121 too!

# %% [markdown]
# Then for this, we don't need to expand the corpus of 'good' texts

# %%
intersected_good_like_bad_comments_2 = good_like_topics.intersection(final_bad_topics_2)
print(len(intersected_good_like_bad_comments_2))
# Out:
# 14

# %% [markdown]
# What about these topics?

# %%
# let's look at comments to these 14 topics

for el in intersected_good_like_bad_comments_2:
    print('#####' * 8 + str(el) + '####' * 8)
    comments_for_this_topic = df_with_comments[df_with_comments.topic_id == el]
    for com in comments_for_this_topic.text.values:
        if len(com) < 10000:
            print(com)
            print('<-------------->')
    print()
# Out:
# ########################################673.0################################
# Typo -  Once you download the executable file for Windows on an archive for Linux
# Must be -  Once you download the executable file for Windows or an archive for Linux
# <-------------->
# How do I learn with no images showing up?
# <-------------->
# I don't know if the website has changed, but using your request 'https://regres.in/api/users/2' gives me a VERY different result in Postman. I'm basically just seeing a JSON version of the DOM for the website.
# <-------------->
# You're trying to get regres.in but examples in the topic use reqres.in
# <-------------->
# Argh! A subtle but important detail! Thanks!!
# <-------------->
# very fascinating. Please add some more explanation about what reqres and postman really are/do. The examples are quite nice but it would be better to explain a bit more in detail about reqres!
# <-------------->
# The name of reqres server is formed from words REQuest and RESponse, so you can send requests to it and get responses back. Its only purpose is to provide some test data with the REST API.
#
# Postman is a client to make requests to any server you like.
# <-------------->
# Ok.
# <-------------->
# There is Advanced REST Client Chrome extension....
# <-------------->
# Make sure to change your settings in POSTMAN according to the images in the theory.
# <-------------->
# by adding some more examples of API
# <-------------->
# In Section §3 POST requests: instructions are unclear. Do I have to change the endpoint to https://reqres.in/api/register ?
# <-------------->
# Give PostWoman a try as an alternative to PostMan. No Download needed.
# <-------------->
# I don't need a postman and never will. Why do you want me to register for a service I don't need? Why would I need to download something to my computer when I'm just studying simple queries? There are many other services for sending requests to the server. Many of them do not require registration and download, many of them work as a browser plugin. Then you test my skills in using the postman service, without which I cannot continue my progress. WHY? Is this an industry standard? Is it strictly necessary for writing a REST service? Does he have no alternatives?
#
# Do you really think that I strictly need a postman to become a Java programmer? It is so necessary that I cannot continue my training until I tell you which buttons must be pressed in this application in order to do something?
#
# I am extremely disappointed. This is just silly.
# <-------------->
# This should be mentioned in the lesson. No download is a big plus for simple experiments.
# <-------------->
# Postman has very nice intro (6 short videos):
# https://www.youtube.com/playlist?list=PLM-7VG-sgbtAgGq_pef5y_ruIUBPpUgNJ
# <-------------->
# In POST requests, second paragraph, the description does not match the picture.  You must follow the picture to get the correct results.
# <-------------->
# §3 for POST method, it is not mentioned in the text to change url to "https://reqres.in/api/register". For clarity ;)
# <-------------->
# It has been rebranded: https://hoppscotch.io/
# <-------------->
# I read everything but I could not understand what this is helpful for and why do I need it.
# <-------------->
# The post part is beyond unclear, I would murder the person who wrote this if I could do it over the internet.
# Since I cant ill just get googling.
# <-------------->
# I would murder the person who wrote this if I could do it over the internet.
# Since I cant ill get googling. cheerios bros.
# <-------------->
# How to implement this in our project "Hypercar Service Center" would be great addition to our learning experience, not sure is it meant to be used or it's just a general knowledge.
# <-------------->
# in the POST request i followed exactly the instruction but in the Body section (x-www-form-urlencoded) it doesn`t show any email data we get in the previous GET request (tracey.ramos@reqres.in)
# <-------------->
# reqres.in has updated some methods
# <-------------->
# I think this is one of the most interesting and most important subjects here. Especially when you are a data analysis enthusiast.
# <-------------->
# why?
# <-------------->
# why not something like httpie? much simpler
# <-------------->
# I followed the steps from the theory section and I got an error on the POST request
# {
#     "error": "Missing email or username"
# }
# I used the email shown in the example and also another email that I got from the previous GET step and the same error appeared. What's the issue?
# <-------------->
# Use request body instead of query parameters to send login and password. It worked for me.
# <-------------->
# The 'raw' option doesn't work for me either ("Missing email or username"), but 'x-www-form-urlencoded' succeeds
# <-------------->
# Please make sure you have 'JSON' selected in the drop-dow control from the right
# <-------------->
# The POST example cannot be reproduced with an anonymous postman account. The answer is always {"error": "Missing email or username"}
# <-------------->
# I would have preferred the explanation on how to use HTTP requests with IntelliJ/PyCharm.
# <-------------->
# You do not need to download Postman to try out the examples in this theory topic. I was able to work through all of them using the browser version of Postman.
# <-------------->
# some parts of text were not really understandable, dunno if i am just stupid or it is badly described
# exactly §3 POST requests, under image, i did not really understood what was talked about
# <-------------->
# After reading theory and practising. I asked my self, how can you get the token without manually copy/paste from Postman to IntelliJ IDEA? Uhm ...
# <-------------->
# post request as written gets an error.  also using patch is not previously introduced
# <-------------->
# quess I'm not the only one who gets their g and q the wrong way round.
# <-------------->
#
# ########################################227.0################################
# fix the misprint mentioned by User 71858
# <-------------->
# val value = "55"
# val currency = "dollars"
# val price = "$value $dollars" // "55 dollars" <- misstype here -- $currency supose to be there
# <-------------->
# val value = "55" val currency = "dollars" val price = "$value $dollars" // "55 dollars" <- misstype here -- $currency supose to be there
# <-------------->
# this article needs in resume or conclusion:
# 1.Use String Templates to insert var and val into String.    "this string has $specialValue"
# 2.If you want to get arbitrary expression (some fields of var or val) - use curly braces.
# "the length of $specialValue is ${specialValue.length"
# <-------------->
# fix mistake with dollars and currency
# <-------------->
# I'd say the article needs proofreading - I see quite a few mistakes in English grammar
# <-------------->
# "Trust no one, homie" :D
# <-------------->
# Why not to add braces when you want to output only value of the variable? I think it makes the code more clear if you always use the same syntax.
# <-------------->
# https://kotlinlang.org/docs/reference/coding-conventions.html#string-templates
# <-------------->
# It may be a convention, but frankly it's a bad one.
# <-------------->
# [Citation Needed] :D
# <-------------->
# The citation is in the lessons.
# <-------------->
# No, it's not. Other languages do it that way, too. It's clearer not using braces, unless absolutely necessary.
# <-------------->
# If you want to do that, you can, but in Kotlin the braces are optional when just resolving a symbol's value, and imo it's much clearer because after the first character that's not a valid variable name it'll continue the regular string
# <-------------->
# Trust no one, homie
# <-------------->
# In my opinion, novice programmers should be introduced about expressions, and probably statements and their differences in programming paradigm before template expressions. I skipped through some study materials since I'm no novice, so might have missed expressions topics earlier.
# <-------------->
# Funny thing I noticed - "$language!" is the same as language + "!", but "$languageXXXX" will generate an error because there's no variable called languageXXXX.
# <-------------->
# Looks similar to f-strings in Python
# <-------------->
# I prefer java style println("Now, the temperature in " + city + " is " + temp + " degrees Celsius.")
# it's better then $bla bla bla
# <-------------->
# Kotlin template is nice and more readable. before Java and Kotlin I preferred C style prints
# printf("Now, the temperature in %s is %.f degrees Celsius", city, temp);
# Although Java has the printf method I prefer Kotlin println over Java and C
# <-------------->
# In that case, you have to use the curly braces:
# val foo = "Foo"
# println("Do you know $foobar?")     // Error, Unresolved reference: foobar
# println("Do you know ${foo}bar?") // prints: Do you know Foobar?
# <-------------->
# Are you sure?
# println("Now, the temperature in " + city + " is " + temp + " degrees Celsius.")
# println("Now, the temperature in $city is $temp degrees Celsius.")
# <-------------->
# It's gone?
# <-------------->
#
# ########################################166.0################################
# This line:
# System.out.println(names); // [Justin, Helen, Joshua]System.out.println(names.size()); // 3:
#
# should be replaced with:
# System.out.println(names); // [Justin, Helen, Joshua]
# System.out.println(names.size()); // 3
# <-------------->
# Grey colour of size() and Object get is in my opinion too light :c
# <-------------->
# "The following example fully demonstrates the listen methods in practice." -> "the listed methods"
# <-------------->
# I think, topic "What are collection" and this topic must coming after "Basics of collections" in the map. Thanks :)
# <-------------->
# it partially repeat other theory about array in different learning tree
# <-------------->
# > "It has methods to get the size and add / access elements..."
# What is the "/"?
#
# +1 for user @timnik below
# <-------------->
# In fact, this class is built on top of a standard Java array, expending it with ...
#
# "expending" -> "extending" or "expanding"
# <-------------->
# "Just try to play with this code and enjoy the powerful of ArrayList :)"
# "enjoy the power of ArrayList"
# <-------------->
# Nice, but you really should add the performance costs vs an normal array and when NOT to use it
# <-------------->
# Possible mistake: "There is only one restriction: ArrayList cannot store primitive types because it is a generic class, but it can store any reference types, including String's, Integer's, other ArrayList's, and custom classes."
#
# Integer is not a reference type.
# <-------------->
# I meant, instead of mentioning Integer's it may say " it can store any reference types, including String's, wrapper classes, other ArrayList's, and custom classes." It wouldn't hurt that this topic includes detailed info about the wrapper class like this: shorturl.at/aHOP0
# <-------------->
# Integer is a wrapper reference type for int.
# <-------------->
# Text has many typos. Although still understandable. I think my assumption of the intended text might be:
#
# Could change the very first sentence to:
# "One of the MOST widely-used classes of the Java Class Library _ is a class named ArrayList. IT represents a resizable array of objects of a specified type."
#
# And I understand the cute expression just before the conclusion should be:
# "It does not look harder than using a standard array NOW it is?"
#
# Never the less thank you for the text.
# <-------------->
# Great material, thanks a lot!
# <-------------->
# "It does not look harder than using a standard array and nor it is."
# The last part should be "is it", it still reads a bit funny.
# <-------------->
# Excellent explanation
# <-------------->
# think you should explain what will be if i create arrayList of ints and try to remove something, how can i remove element by its value and so on
#
# ArrayList<Integer> list = new ArrayList<>();
# list.add(1);
# list.add(2);
# list.remove(1);
# System.out.println(list);  // [ 1 ]
#
# list.clear();
# list.add(1);
# list.add(2);
# list.remove(Integer.valueOf(1));
# System.out.println(list);  // [ 2 ]
# <-------------->
# Important note: "remove" method removes only the first occurrence of the specified element from this list, if it is present.
#
# ```
# List<String> items = new ArrayList<>(Arrays.asList("Alpha", "Beta", "Alpha"));
# items.remove("Alpha");
# System.out.println(items);
# ```
#
# Will print `[Beta, Alpha]`
# <-------------->
# Important note: "remove" method removes only the first occurrence of the specified element from this list, if it is present.
# <-------------->
# You could iterate (loop over) the collection and check if it contains the value you're looking for using the contains(Object o) method.
# <-------------->
# "it can dynamically grow after the addition and shrink after the removal of its elements", here I think its worth mentioning that it can shrink manually, correct me if I am wrong.
# <-------------->
# Weak example with `indexOf()` and `lastIndexOf()`. It is a bad idea to use integers as values for demonstration of the integers result of index. You can use strings at least. Names. Any other words. That will be less blurred.
# <-------------->
# `ArrayList.addAll(Collection c)` may be a good addition to the list of common methods
# <-------------->
# I think the definition of remove methods is messed up a little bit. Right now, it says:
# remove(Object o) removes the object;
# remove(int index) removes the first occurrence of the element with a given index;
# Shouldn't it be like this?
# remove(Object o) removes the first occurence of the object;
# remove(int index) removes the element with a given index;
# <-------------->
# i totally agree with that
# please report that here https://support.hyperskill.org/hc/en-us/requests/new
#
# and have a nice day :)
# <-------------->
# Agree. I was about to write the same comment.
# <-------------->
# Damn, I am forever spoiled by the perl and ruby array implementations, I hate how cumbersome even ArrayLists handle in java.
# <-------------->
# "remove(int index) removes the first occurrence of the element with a given index"?????
#
# what does this mean?
# <-------------->
# remove​(int index) - removes the element at the specified position in this list
# remove​(Object o) - removes the first occurrence of the specified element from this list, if it is present
#
# This are accurate definitions from docs.
# <-------------->
# remove​(int index) - removes the element at the specified position in this list
# remove​(Object o) - removes the first occurrence of the specified element from this list, if it is present
#
# These are accurate definitions from docs.
# <-------------->
# it's typo
#
# remove (int index) should remove the element at that index
# but remove(object) should remove the first occurrence of that object in the arraylist
#
# please report it here
#
# https://support.hyperskill.org/hc/en-us/requests/new
# <-------------->
# Why don't you guys change it in the question then?
# <-------------->
# Mods can't change provided content. So, all of these typos and mistakes are better be reported via support. You can just write it in comments, but it easily can be lost.
#
# I see that someone has noticed that the definitions are swapped like a month ago. So, if the guy didn't reported it, then it just got lost among other comments. If he reported, then I have no idea why it's not fixed. (:
# <-------------->
# NVM i have reported it maybe it will be fixed....:)
# <-------------->
# Why it`s better to use List<String>  list = new ArrayList<>(); than ArrayList<String>  list = new ArrayList<>() ? Can someone explain?
# <-------------->
# It makes your code more flexible to change and less dependend on specific implementation.  For example you could swap new ArrayList<>() to new LinkedList<>() and the methods from List interface will still work.
# <-------------->
# "remove(Object o) removes the object;
# remove(int index) removes the first occurrence of the element with a given index; "
# You probably meant that remove(Object o) removes the first occurrence because it's nothing unexpected for remove(int index).
# <-------------->
# I think it's bad that you don't write returning type when introducing a new method. For example is a good practice to write "boolean remove(Object o)" or even "public boolean remove(Object o)" instead of just "remove(Object o)".
# I was thinking if there is a method to remove all occurrences of an object. If not, it could be easily written, knowing remove() returns boolean - true if the element to remove was in the ArrayList, false otherwise. So you just write:
#
# boolean isStillInList = true;
# while (isStillInList)
#    isStillInList = remove(objectToDelete);
#
# or even simplier:
#
# do {} while(remove(objectToDelete));
# ---
#
# One more thing - this paragraph of declaring List instead of ArrayList intrigued me. Could someone give me a link to a lesson where it's better explained?
# <-------------->
# you can use removeIf
# https://docs.oracle.com/en/java/javase/11/docs/api/java.base/java/util/ArrayList.html#removeIf(java.util.function.Predicate)
#
# you well learn about this on stream lesson
# also all remove return boolean public boolean remove​(Object o)
# https://docs.oracle.com/en/java/javase/11/docs/api/java.base/java/util/ArrayList.html#remove(java.lang.Object)
#
# and it good practice to use the List to declare the variable cause at any time in the code if you want to change the refrence type in the code it would still work
# so maybe in part of code i want to do this
# List<type> variable = new arrayList<>() ;
# and later i find that it would be better to make it linkedList
# then i can do that
# variable =  new LinkedList(variable);
# then my code still valid as both type of List
#
# one note using this way and using the magic of inheritance each call to any method would call the lowest implementation in the hierarchy of the inheritance which help
# but remember variable can call only the method defined on the list so if there other method in arraylist for example not defined in the list interface then i would not call it unless i cast it
# but of course it recommend to use this way for it flexibility to assign it to any type of same hierarchy
# also use this way for your own class so assign variable to the parent class/interface unless if you want to call subclass method a lot and do not need to change type
#
# hope that help and have a nice day :)
# <-------------->
# please move the text to correct method "the first occurrence of the element"
# remove(Object o) removes the object;
# remove(int index) removes the first occurrence of the element with a given index;
# <-------------->
# "If you are an advanced user, you know that it is better to create and use an ArrayList via its List interface. We will do it in the next lessons after learning inheritance."
#
# Can someone give more detailed explanation or some practical examples...?
# <-------------->
# Here's an example: List<String> list = new ArrayList<>();
# The main reason you'd do this is to decouple your code from a specific implementation of the interface. This is preferable because the rest of the code only knows that data is of type List and hence you can switch between different implementations of the List interface with ease.
# <-------------->
# https://stackoverflow.com/questions/2697783/what-does-program-to-interfaces-not-implementations-mean
# <-------------->
# 9 months later...no correction applied...
# <-------------->
# Not too shabby! Amazing!
# <-------------->
# Is there a way to remove integer element from ArrayList with list.remove(number)?
# The number can be indicating both index or the object.
# <-------------->
# Yes, there is a way: cast yuor number to Object. Try this example:
#
#     public static void main(String args[]) {
#         List<Integer> list = new ArrayList<>();
#         list.add(1);
#         list.add(2);
#         list.add(3);
#         list.add(1);
#         System.out.println(list);
#         list.remove((Object)1);
#         System.out.println(list);
#     }
# <-------------->
# not bad)
# <-------------->
#
# ########################################6.0################################
# Please write more on this topic .What is covered barely touches the subject.
# <-------------->
# Would be helpful to have a little blurb on what boxing and unboxing is useful for.
# <-------------->
# Please, after text %Integer number = new Integer("10012"); //.....
#
# replace comment by real code as above for Integer - because the comment not convient to read.
# <-------------->
# what is the difference between parseLong and valueOf? which one should be used?
# <-------------->
# you may want to warn from using wrappers at all and utilizing collecitons from custom libraries with direct support of primitives
# <-------------->
# It would be nice to tell readers that the type of conditional statement used for preventing a null pointer exception is called a Ternary and it will be studied in later courses.
# <-------------->
# Note: the conditional used for preventing null pointer exception when auto-unboxing is called a Ternary.
# <-------------->
# Note: the conditional statement used for preventing null pointer exception when auto-unboxing is called a Ternary.
# <-------------->
# In the reflection section of this project, it should be feedback sent, not feedback sended.
# <-------------->
# "The following table list" should be "...lists".
# <-------------->
# parseLong() reads a value from a String. valueOf() takes the value of a Long reference and passes it to the primitive long object.
# <-------------->
# in "theory block above" valueOf is used like this: Long.valueOf("2000");
# <-------------->
# I suggest you have a look at these methods in the IDE. I just did and from what I can tell, parseLong() takes a String and returns a primitive long. valueOf() can take a String or a primitive long and returns a Long wrapper class object.
# <-------------->
# In paragraph 6 it uses the words "to sum up" but then mentions the fact that primitive types process values faster. This was nowhere mentioned in the text though.
# <-------------->
# We should use primitive types wherever is possible. Object in Java occupy a minimum of 16 bytes when primitive types are less memory-eating. For example int is 4 bytes when Integer is 16 (so 4 times more). Boolean is 16 bytes when boolean is 1 bit.
# <-------------->
# What is generic collection?
# <-------------->
# So generic collection is standard collection, am I right?
# <-------------->
# Variable of Boolean can be true, false and null - ternary logic in Java!
# <-------------->
# Java also have wrapper class for void.
# <-------------->
# Java also has wrapper class for void.
# <-------------->
# remember:
# Integer.valueOf(120) == Integer.valueOf(120) //true
# Integer.valueOf(200) == Integer.valueOf(200) //false
# <-------------->
# Amazing theory, especially the extra notes, explaining what is fastest, how to deal with NPE's and when mentioning something like standard collections, specifying that it will be learned later and does not need to be thought about right now. This is what makes great theory!
# <-------------->
# Why do we care about wrapper classes? I feel like I have no sense for when we'd ever want to use one, or why using one is bad practice if we don't
# <-------------->
# Why do we care about wrapper classes? I feel like I have no sense for when we'd ever want to use one, or why using one is bad practice if we don't
# <-------------->
# The wrapper classes constructor arguments were deprecated as of Java 9.
# <-------------->
# So, Section  §3. Constructing wrappers based on other types
# utilizes Deprecated code as of Java 9.
# <-------------->
# "primitive types cannot be used in standard collections (like lists, sets, or others), but wrappers can"
# Note that you might feel like you can create a collection of primitives, for example:
# List listOfNumbers = new ArrayList();
# listOfNumbers.add(1);
#
# But there is auto-boxing, so the "1" here is like a "new Integer(1)", even if it's opaque. That's why it's said that you can't use primitives in collections.
# <-------------->
# Quite hard to understand and no idea what the use case scenario for any of this is
# <-------------->
# Long longNumber = new Long("100000000"); //has been deprecated since Java 9. Can anyone explain?
# <-------------->
# Yeah, it means if you're using a version of Java 9 or later, then you have to write it as:
# Long longVal = Long.parseLong("1000");
# <-------------->
# I don't understand why and when should I use this.
# <-------------->
# use primitive type as much as you can cause they faster  unless
#
# 1) you do not want to set that variable to any default value then wrappers can be used when you need null as a no-value indicator
# 2) some class specially many generic one does not accept primitive type then you would use wrappers
# you will learn about generic classes later if you not already did
#
# hope that help and have a nice day
# <-------------->
# Thank you for your response, it definitaly helped!
# <-------------->
# you welcome :)
# <-------------->
# patrick
# <-------------->
# Paragraph 5 :
# Your advice to fix NPE :
#  long unboxed = val != null ? val : 0;
#
# When we apply this advice in the follow exercices, it is considered as a bad practice :
# "Ternary operators that can be simplified with || or &&"
# There you prefer us to use :
# long unboxed = val != null && val
# <-------------->
# Your code isn't correct because return boolean value but you need long
# <-------------->
# Hi, salut !
# You're right indeed. The exercice uses a boolean.
#
# So, with val a Boolean object :
# boolean isTrue = val != null ? val : false
# is considered as a bad practice in the exercice, where you have to write :
# boolean isTrue = val != null && val.
#
# Thanks for your reading and correction.
# <-------------->
# Hi, salut !
# You're right indeed. The exercice uses a boolean.
#
# So, with val a Boolean object :
# boolean isTrue = val != null ? val : false
# is considered as a bad practice in the exercice, where you have to write :
# boolean isTrue = val != null && val.
#
# And since here we use a long, I wasn’t thinking hard enough and I was wrong to warn.
# Thanks for your reading and correction.
# <-------------->
# Not big deal.
# We all learn and teach one another :)
# <-------------->
# "== checks whether two wrapper objects are actually equal"
#
# Bad use of the word "actually" here.
# <-------------->
# "Note, since Java 9, the constructors are deprecated. You should use special methods to create objects of the wrapper classes." HOLY COW! Please GIVE AN EXAMPLE CONTRASTING THE DEPRECATED METHOD TO THE PREFERRED ONE!
# <-------------->
# For a related explanation, search for the concept of Java Constant pool
# <-------------->
# You don't know why? Read the article below:
#
# http://java-latte.blogspot.com/2013/11/java-integer-constant-pool.html
# <-------------->
# I thought Integer was 32 bit? Am confused now
# <-------------->
# it's fine if you have seen this before but I would not feel comfortable with this if it was the first time. However, it is not a bad idea for a beginner to look into documentation and other material, Java is a complex language that requires a lot of commitment
# <-------------->
#
# ########################################232.0################################
# "otherwise, the it is false" -- an unnecessary article
# "Sometimes we even do need to declare a new variable" -- perhaps, "do not"?
# <-------------->
# Seems like there is a mistake.
# "Sometimes we even do NOT need to declare a new variable for storing a result."
# <-------------->
# Typo?
# Noe that the situation when they both are executed is impossible.
# <-------------->
# "Unlike other languages (such as Java, Python, C#)..."
# I find it very interesting that JetBrains left out C/C++...
# <-------------->
# The chess questions are absolutely horrid, especially if you're not a chess player. I hated them so much, I feel like I'm done with this stuff if this is how the course continues.
# <-------------->
# A mistake: in 1§ last block of code:
# val b = ... // it is true oF false (Boolean)
# <-------------->
# "This code tests the value is divided by 2 and, if it is true, tests the value is divided by 3. If it is also true, it means the value is divided by 6."
#
# Replace the words divided with divisible.
# <-------------->
# Does this mean there is no ternary in Kotlin? And can I inline multiple else-ifs, like val something = if expr0 res0 else if expr1 res1 else if expr2 res2 [...] else if expr[n-1] res[n-1] else res[n] ?
# <-------------->
# Yes, there is no ternary operator in Kotlin.
# <-------------->
# I doubt they meant anything by that. After all, they can't name every single programming language, since there are hundreds, if not thousands.
# <-------------->
# "Sometimes we even do NOT need to declare a new variable for storing a result. In this example, we compare two numbers and print the text information passing it to a function."
#
# The code that follows shows the three branches printing some text depending on the comparison of the values, but it doesn't seem to show anything passing to a function.  Or am I missing something?
# <-------------->
# Very different to python indeed
# <-------------->
# It has a typo in the "computer cost" part. In the code, it says "else if (dollars < 100_000)" but in the text it says "else if (dollars < 10_000)"
# <-------------->
# Instead of assigning the result of the if/else conditional statement to a variable and then using println() to print the variable, the result is passed to the println() function directly by including it in the parenthesis.
# <-------------->
# The codeblocks both ended with the value to be returned:
#
# val max = if (a > b) {
#     println("Choose a")
#     a       //  <=== Returns a as a result to be assigned to max
# } else {
#     println("Choose b")
#     b       //  <=== Returns b as a result to be assigned to max
# }
# <-------------->
# Perhaps using colors to differentiate nested codes would be useful.
# <-------------->
# ’If all the bodies contain only a single statement, you can skip braces:’
#
# What does "single statement" mean here? is it a natural English statement or a programming statement?
#
# When does a conditional's body tend to have single-line property?
#
# Thanks for any explanation, friends.
# <-------------->
# that function is println()
# <-------------->
# I did not like ternaries anyway
# <-------------->
# It is programming statement, like this example:
#
# if (1 == 1) {
#    println("this if")
#    println("has multiple statements (commands) ")
#    println("and need braces")
# }
#
# if (2==2) println("But this has only one statement. You don't need braces")
# <-------------->
# Thank you very much for your wonderful explanation.
# <-------------->
# Article touches topic of nesting if's but doesn't touch return-early.
# <-------------->
# At least write the difference of the else if expression, not just the syntax
# <-------------->
# get ready to learn irrelevant shit in these practice question.... waste of fucking time #teamtreehouse is sooo much better... i didnt come here to learn about chess stupid mf's
# <-------------->
# Would it make sense to introduce the 'when' statement here? I really prefer it compared to the multiple if / else if syntax.
# <-------------->
# In my opinion, it is bad practice to do if-else logic inside a print statement.
# But in the practice exercises (and theory) about this subject you will see code structured as
# "println(if ... ... else ... ...)"
#
# If it was me, I would tell people to do the printing inside the body (aka inside the {} brackets)
# So it can't interfere with the code handeling the if-else logic.
#
# If, besides having to write print less often, there are compiler/optimization reasons for doing it inside the print statement, feel free to enlighten us all.
# <-------------->
# I have no idea how the syntax is supposed to work here. I'm trying to say that if(year / 4 && !(year / 100)) etc... but, that's a boolean, how the hell do you separate these two equations? A comma? The examples they give us are no simple I have to painfully scour the internet, hints, to get some of these answers right. They make you writhe to solve each problem. Which is good to an extent, but I waste so so much time on these problems lol.
# <-------------->
# I came up with a cool idea... !/ which is NOT divisble by, except that probably doesn't exist. I have no idea how to join two conditions under the same if.
# <-------------->
# Finally I could understand it! I'm so glad \o/
# <-------------->
#
# ########################################998.0################################
# What about "finally" block?
# <-------------->
# Kotlin still does not support catch handler for multiple exception types? Jeee-sus.
# <-------------->
# stdlib contains very useful runCatching method:
# https://kotlinlang.org/api/latest/jvm/stdlib/kotlin/run-catching.html
# <-------------->
# I recently found a shorter way of handling several exceptions with try-catch statements:
#     try {
#         // code that throws exceptions
#     } catch (e: Exception) {
#         val message = when (e) {
#             is IOException -> "handling the IOException and its subtypes text goes here"
#             is ArithmeticException -> {
#                 // code could go here
#                 "handling ArithmeticException text goes here"
#             }
#             else -> "catch unknown errors text goes here"
#         }
#         println("$message: " + e.message)
#     }
# And then medium.com has an article about using runCatching mentioned in below message, and the problems that can arise if one doesn't take the proper steps for different exceptions, which can be a problem for try-catch as well:
# https://medium.com/@mattia23r/a-take-on-functional-error-handling-in-kotlin-515b67b4212b
# Like this is one of their examples of using runCatching:
# runCatching {
#   doSomeRiskyWork()
# }.onFailure {
#   print("Something wrong happened: ${it.message}")
# }
# And then they said it would be better to do this with runCatching instead, as it's better to handle known exceptions that might occur:
# runCatching {
#   doSomeRiskyWork(riskyArgument)
# }.onFailure { // it: Throwable ->
#   when (it) {
#     is IllegalArgumentException -> {
#       showProperFeedback()
#     }
#     is IllegalStateException -> {
#       handleThisCase()
#     }
#     else -> throw it
#   }
# }
# <-------------->
# That will be covered by another topic!
# <-------------->
# The code quality checker gives us a problem if we format our code the way you do in the theory.  The checker wants us to write the code like so:
# try {
#     // code that may throw an exception
# } catch (e: SomeException) {
#     // code for handling the exception
# }.
# In the theory, the code is coming out like so:
# try {
#     // code that may throw an exception
# }
# catch (e: SomeException) {
#     // code for handling the exception
# }
# Which the code checker doesn't like.
# <-------------->
# Why is the following not a compile-time error in Kotlin?
# try {
#         throw ArithmeticException()
# } catch (e: Exception) {
# } catch (e: ArithmeticException) {
# }
# <-------------->
# In Section "The try-catch statement", second paragraph after the first code example, it says
# "In the presented template, the catch block can handle exceptions of the Exception type and all types derived from it."
#
# But in the above code example we have
# catch (e: SomeException)
#
# So, it should probably be "exceptions of the _SomeException_ type ".
# <-------------->
# Put some images with naked women here please. It would help a lot.
# <-------------->
# Actually it does because there is an issue how curly braces are put but beside that why should you get compile error? You can throw an exception inside any block and try-catch is included
# <-------------->
# Curly braces are placed correctly. If you try to compile such construct in Java, it will give you a compile-time error, hence my question. The reason why this fails in Java is because the second catch clause is pointless as it will never be executed due to a broader exception type in the first catch clause.
# <-------------->
# The following example demonstrates the execution flow with try and catch:
#  println("Inside the try block after the exception") // it won't be printed -> it printed too!!
# The output:
#
# Before the try-catch block
# Inside the try block before an exception // it printed here !!
# Division by zero!
# After the try-catch block
# <-------------->
# The following example demonstrates the execution flow with try and catch:
#
# println("Before the try-catch block") // it will be printed
# try {
#     println("Inside the try block before an exception") // it will be printed
#     println(2 / 0) // it throws ArithmeticException
#     println("Inside the try block after the exception") // it won't be printed -> but it printed too!
# }
# catch (e: ArithmeticException) {
#     println("Division by zero!") // it will be printed
# }
#
# println("After the try-catch block") // it will be printed
# The output:
#
# Before the try-catch block
# Inside the try block before an exception // printed here!! I also tried in IntelliJ and the result is the same!
# Division by zero!
# After the try-catch block
# <-------------->
# This was amazing thanks for posting it here!
# <-------------->
# "SomeException" can be a special Exception type implemented by the programmer, that inherits from any Exception, thus also from the super-type exception... So any Exception is also from type Exception. Also, I think, "SomeException" is only an example here.
#
# This is only my observation. Correct me if I am wrong :-)
# <-------------->
# "SomeException" can be a special Exception type implemented by the programmer, that inherits from any Exception, thus also from the super-type Exception... So any Exception is also from type Exception. Also, I think, "SomeException" is only an example here.
#
# This is only my observation. Correct me if I am wrong :-)
# <-------------->
# Strange... So if the first catch is applied to the Exception, why should "the program care", if the following catch blocks are suitable for this Exception..? Btw, I am quite new to this and am not very knowlegebal.. Just wondering.
# <-------------->
#
# ########################################585.0################################
# I'm sorry I have to say this: I got the opposite impression during reading this text. The example looks more like a subject for a loop, I think! Maybe a tree-based problem would be better?
# <-------------->
# maybe you guys could point our how to solve matricx determinants using a recursion method. not the math behind it, just use it as an example, if that makes any sense?
# <-------------->
# the 'start' parameter confused me until I realized the initial / outermost value is always zero.  Before that, I thought you were writing a function that had an arbitrary start.  Adding a phrase like 'initially, zero' after 'from where to start the search' in the paragraph beginning 'Our recursive function' would have helped me.
# <-------------->
# A question as I'm new to this:
# Wouldn't it be better if we modify the elif statement like this:
#
#     elif i == len(word) - 1:
#         if (previous_char in vowels) and (word[0] != "'"):
#             return i
#         return -1
#
# considering that the last character would be diacritic if the first character is not a quotation mark. Or am I missing something?
# <-------------->
# A loop would be much better for given example!
# <-------------->
# Loops would be better for given example.
# <-------------->
# This example is more confusing than helpful for demonstrating the power of recursion imo...
# <-------------->
# 1) Theory should be clarified and fixed.
#
# 2) How one can claim that eating candy is recursive but not an example of a loop? You can fix it with each  candy should be eaten and its package should be thrown away. So, one can eat and throw away package is an example of loop but opening all packages and then eating when all candies opened and throwing packages away is recursive.
#
# 3) Factorial example should be fixed as like:
#
# 5! = 5 * 4!  = 5 * 4 * 3! = 5 * 4 * 3 * 2! = 5 * 4 * 3 * 2 * 1
#
# this is more understandable for the topic.
#
# 4) This has not seen:
#
# So, as you have seen, this task can be quite easily solved with the help of recursion, and solving it using loops would be much less natural.
# <-------------->
# In order to define recursion, we must first define recursion.
# <-------------->
# comparison with same problem solved using loops would make a much stronger case for recursion
# <-------------->
# According to the complains of follow comments, maybe should consider using "Towers of Hanoi" to show the power of recursion.
# <-------------->
# This one did not help in understanding recursion at all
# <-------------->
# I agree!
# <-------------->
# Agree WY
# <-------------->
# the problem recursion is solving seems a little forced
# <-------------->
# The example is hard to understand.
# <-------------->
# Honestly, I think everyone would be better off if they just skipped reading this one.
# <-------------->
# I can't believe how well-written this piece is! And I'm not joking, like seriously! 💕
# <-------------->
# I think the solution to this particular problem looks more concise and intuitive with a for-loop. But the rest of the theory on recursion is clear, thanks!
# <-------------->
# "#  the apostrophe is the last symbol, doesn't meet the condition"
# Who wrote this? What about Portuguese for "hello": Olá (Ola') ?
# <-------------->
# Well, I do not see the benefit over using the for loop. If that was compared and explained maybe I would find the recursion useful. So far while and for sounds like better option as it is easier to write. Or is the recursion at least quicker? I do not know, can you please explain more in details?
# <-------------->
# Well, I do not see the benefit over using the for loop. If loops and recursions were compared and explained for differences maybe I would find the recursion useful. So far while and for sounds like better option as it is easier to write. Or is the recursion at least quicker? I do not know, can you please explain more in details? MUch less natural does not really help when the loop is currently more natural while learning Python...
# <-------------->
# Recursion golden era is gone - it was times when "for i=0; i<10; i=i+1"  was the only way to loop in most of languages, and using function was a top standard like using objects today. There was not much other options and people did magic using recursion. Some of them are teaching now forgetting that world of codding changed dramatically.
# <-------------->
# wouldn't something like this be easier to read or write?
#
# def find_apostrophe(word, start=0):
#
#     i = word.find("'", start)
#
#     if i == -1:
#         return -1
#     elif i == 0 or i == len(word) - 1:
#         return -1
#     else:
#         previous_element = word[i - 1]
#         if previous_element in vowels:
#             return i
#         return -1
# <-------------->
# wouldn't something like this be much easier to write and read while doing same thing?
#
# def find_apostrophe(word, start=0):
#
#     i = word.find("'", start)
#
#     if word[i - 1] in vowels:
#         return i
#     return -1
# <-------------->
# wouldn't something like this be much easier to write and read while doing same thing?
# def find_apostrophe_without(word, start=0):
#     i = word.find("'", start)
#     if word[i - 1] in vowels:
#         return i
#     return -1
# <-------------->
# I understood the concept of recursion with this example. However, It didn't become clear to me how it is better than using a loop. I think a precise comparison of the two alternative solutions (recursion and loop) with pointing out the strengths of recursion might have helped here.
# <-------------->
# I don't know. If you say it saves programmers time when writing the code, it definitely does help others trying to understand it. My head is about to explode every time I am looking at a recursive function...
# <-------------->
# Well, if you say it saves programmer's time when writing it, it definitely does NOT help others trying to understand it. My head is about to explode every time I am looking at a recursive function...
# <-------------->
# Not really obvious why loop would be worse. It seems natural to loop from 1 to -1, ignoring first and last characters.
# <-------------->
# missing all the edge cases.
# <-------------->
# def find_apostrophe(word, start):
#     for i, character in enumerate(word[start:-1], start):
#         if character == "'":
#             if i == 0:
#                 continue
#             else:
#                 if word[i - 1] in vowels:
#                     return i
#     else:
#         return -1
# <-------------->
# Hi! Don't forget the fact that recursion is a must-know topic about mathematical functions (a basic topic), and programming derives from Maths. It just seems weird if it's the first time you see it, but it's a very powerful method along with loops. Both have their issues depending on the implementation.
# In a loop, it could be straightforward knowing what to do in each step (and they are better in imperative languages), but recursion is better for a mathematical description of what's going on and how the problem is solved (it should be much faster in functional languages)
# <-------------->
# You still have to initialize a variable with the base case/accumulator and to specify a start, a stop and an increment with Python for loops, am I wrong? But not even at the same line, so
#
# >IDK how to define fxs in Java<
# int n = 1;
# for (int i=5; i > 0; i--) {
#     n = n * i;
# }
#
# VS
#
# def loop_fact(n):
#     t = 1
#     for i in range(1, n + 1):
#         t *= i
#     return t  # faster
#
# VS
#
# def rec_fact(n):
#     return 1 if not n else n * rec_fact(n - 1)  # concise
#
# Now getting fibonacci by index would be
#
# def rec_fibo(n):
#     return n if n < 2 else fibo(n - 1) + fibo(n - 2)
#
# VS
#
# def loop_fib(n):
#     a, b = 1, 1
#     for n in range(n - 1):
#          a, b = b, a + b
#     retrun a
#
# Performance will always depend on the implementation, but recursion gets easier -compared with loops- the more complex the problem gets.
# <-------------->
# You still have to initialize a variable with the base case/accumulator and to specify a start, a stop, and an increment with Python for loops, am I wrong? But not even at the same line, so
#
# >IDK how to define fxs in Java<
# int n = 1;
#     for (int i=5; i > 0; i--) {
#         n *= i;
#     }
#
# VS
#
# def loop_fact(n):
#     t = 1
#     for i in range(1, n + 1):
#         t *= i
#     return t  # faster
#
# VS
#
# def rec_fact(n):
#     return 1 if not n else n * rec_fact(n - 1)  # concise
#
# Now getting Fibonacci by the index would be
#
# def rec_fibo(n):
#     return n if n < 2 else fibo(n - 1) + fibo(n - 2)
#
# VS
#
# def loop_fib(n):
#     a, b = 1, 1
#     for n in range(n - 1):
#          a, b = b, a + b
#     retrun a
#
# The performance will always depend on the implementation, but recursion gets easier -compared with loops- the more complex the problem gets.
# <-------------->
# This part of the example is not very clear:
#   previous_char = word[i - 1]
#         if previous_char in vowels:
#             return i
# <-------------->
# Solving this example with loops WOULD be much natural.
# <-------------->
# There is a max recursion depth in python.
# <-------------->
# Second example is not clear. You didn't convince me, that recursion is better than a loop here.
# <-------------->
# You would then need to take into account that the first char in the index is not an apostrophe, and that the next char from the apostrophe in Ola' is not another apostrophe.
# <-------------->
# Still fairly confused with recursion, but like with everything else, practice makes perfect.
# <-------------->
# 999 on my machine ;)
# <-------------->
# In 80s with computer RAM counted in megabytes each character saved in code was worth to save ;)
# <-------------->
# The second paragraph should not exist.
# <-------------->
# The second paragraph should not exist.
# <-------------->
# Ahem, "When not to write useless paragraphs"...
# <-------------->
# When not to loop? -> When not to write useless and terrible paragraphs...
# It's a very wrong decision, to try to explain a concept (BTW, not that complex one) with a convoluted, complex and questionable example.
# <-------------->
# One of the best practically applied lesson. I had a task for the job application test on Test Gorilla, and for that time I wasn't  aware of function recursion, that was the key idea in solution, so I failed that part of the test.
# <-------------->
# Do You really think recursion for finding vowel+' is more natural?
# I do not.
#
# Iterating over string using length from 1 to n-1 seems more natural to me.
# Not even taking to account resources needed.
# <-------------->
# ...
# Here's a variation of the Sun class that only allows you to have one instance of the class, even when you invoke the constructor multiple times:
#
# class Sun:
#     # instance variable starts as None,
#     # meaning no instance has been created yet.
#     instance = None
#
#     def __new__(cls):
#         if cls.instance is None:
#             cls.instance = object.__new__(cls) # Create new object if instance is None
#         return cls.instance # Return the instance
#
#
# a = Sun()
# b = Sun()
# print(a)  # <__main__.Sun object at 0x000001BB7348A160>
# print(b)  # <__main__.Sun object at 0x000001BB7348A160>
# <-------------->
# I'm still not sure what most of these do..
# <-------------->
# Too complicated and you need to add more practical examples. The difference between str and repr is not obvious.
# <-------------->
# a little more about "why?"
# <-------------->
# f u
# <-------------->
# Hello i have a PyCharm Professional 2021.1 versión and follow this example that it indicates some error, but in Pycharm run without error. Greetings.
#
# Seguí este ejercicio en Pycharm donde se indica que ocurre un error, pero en el IDE no genera el error. He notado algunas diferencias en el IDE y la versión de esya plataforma en línea, saludos.
# <-------------->
# a bit superficial
# <-------------->
# repr() was not explained anywhere before (except a two sentence example wthin the "escape sequence" chapter - of course?!?!?!?), so what do you think how easy is this reading to follow?
# <-------------->
# Too few examples for such confusing topic
# <-------------->
# interesting and useful :)
# <-------------->
# why does the repr provide less information in the examples?
# <-------------->
# Why is the __repr__ method less expressive than __str__ in the example? shouldn't it be the other way around????
# <-------------->
#
# ########################################121.0################################
# This lesson is terribly written and full of grammar mistakes. D:
# <-------------->
# Order of initialization:
# 1. Is there a superclass? initialize it first(using implicit super constructor or an empty one)
# 2. Static variable declaration and static initializers in the same order they appear in the class
# 3. Instance variables and instance initializers block in the same order they appear in the class
# 4. The class constructor
# <-------------->
# The example with "Before the constructor" output should actually include a no-arg constructor that prints "In the constructor" for clarity.
# <-------------->
# I did not fully understand, in which cases i would need it. If i want to initialize an array, why not in the constructor?
# <-------------->
# unclear
# <-------------->
# Not enough detail
# <-------------->
# I don't understand why you can't just write the code below and eliminate the need for static initialization blocks.
#
#     private static String stringField = getEmptyString();
#     private static Date dateField = new Date();
#
#     private static final String A_STRING_CONSTANT = "unknown";
#
#     private static String getEmptyString() {
#         return "empty";
#     }
# <-------------->
# They are just showing to us how we can use static blocks.
# <-------------->
# why this was ever introduced? and what kind of tasks we gonna solve with it in the cousre?
# <-------------->
# As to the why behind the theory:
#
# The static initializers are executed only once during runtime, specifically during loading of the class.  A use case for the static initialization block would be a JDBC  driver that registers itself to a DriverManager.
#
# The instance initializers are executed regardless of which constructor is used.  You can have a common shared initialization for the class without duplicating code in each constructor.
# <-------------->
# We could access to uninitialized default of value fields in the block above of initialization. So direct assignment operation hasn't priority over init-blocks. They just placed in order of presenting in source code and merge to one <init> or <clinit> method in bytecode.
#
# Example:
#
# public class Main {
#
#     static {
#         System.out.println(Main.staticField);
#     }
#
#     private static int staticField = 1;
#
#     static {
#         staticField = 42;
#         System.out.println(Main.staticField);
#     }
#
#     {
#         System.out.println(this.instanceField);
#     }
#
#     private int instanceField = 1;
#
#     {
#         instanceField = 42;
#         System.out.println(this.instanceField);
#     }
#
# }
# <-------------->
# Some information on why you would use this construction and in what cases would be much appreciated.
# <-------------->
# class Parent
# class Child extends Parent
#
# order:
# 1)Parent static block
# 2)Child static block
# 3)Parent initialization block
# 4)Parent Constructor
# 5)Child initialization block
# 6)Child Constructor
# <-------------->
# a table about the order of initialization of fields, methods and blocks is needed
# <-------------->
# Very important notes, I think those should be in the theory section.
# Many thanks!
# <-------------->
# I found the notes in the comment bellow very important to know, and I think it would be great if add to the theory.
# https://hyperskill.org/learn/step/3533#comment-520473
# <-------------->
# and notice that
# 2. Static variable declaration and static initializers in the same order they appear in the class called only once not per object
# <-------------->
# More examples where to use this topic!
# <-------------->
# не ясно, зачем это
#
# почему этот урок появился в стадии 1, которую я завершил давно?
# <-------------->
# Had to google about what benefits an "instance initialization block" offers.
# As I understand they are:
# - the block is invoked no matter how many constructors the class has
# - it can be used in anonymous classes where it's impossible to use a constructor
# <-------------->
# If we have super class and subclass then the order of initialization is:
# 1) Superclass' static block
# 2) Subclass' static block
# 3) Superclass' initialization block
# 4) Superclass' constructor
# 5) Subclass' initialization block
# 6) Subclass' constructor
# <-------------->
# A static initialization blocks is required when you need to write some instructions to initialize a static variable.
# If you can write directly something like "static Type myVariable = value", the block usage is useless.
# For clarity, don't use multiple static blocks and write it in the same location of your code than the static variables declaration.
#
# An instance initialization block performs common code for all instanciations, but hides the logic of each constructor. Its usage is discouraged when you can use constructors.
# <-------------->
# A static initialization block is required when you need to write some instructions to initialize a static variable.
# If you can write directly something like "static Type myVariable = value;", the block usage is useless.
# For clarity, don't use multiple static blocks and write it in the same location of your code than the static variables declaration.
#
# An instance initialization block performs common code for all instanciations, but hides the logic of each constructor. Its usage is discouraged when you can use constructors.
# <-------------->
# Does not offer any insight on why an instance initialization block is preferable, nor why multiple of them make sense.
# <-------------->
# Ok, let me ask which method should I choose in case for example I have to create bank account with account number.
# I have field private long accountNumber
# Should I create method private long createAccountNumber(); and invoke it in constructor this.accountNumber = createAccountNumber();
# or
# private long accountNumber;
# {
#      //  algorithm to creating account number
# }
# Which is considered as better practice?
# <-------------->
# I know that many people consider it bad practice to invoke instance methods from a constructor. That's because the object isn't completely created before the constructor finishes. So if you don't want to place too much code in your constructor, you can either use an initialization block or make something like:
# private static long initAccountNumber() { // method logic }
# Notice that it's static so it can be invoked from the constructor safely
# <-------------->
# Oh, sounds good.
# I oversighted this point.
# Thx
# <-------------->
# Conceptually I can understand the first bonus you mention, but I still find it odd that we don't use an init() method or something of the sort that's simply called in every constructor and provides better context.
#
# Did you find any examples and real-life use-cases?
# <-------------->
# OK, nice theory, but why would anyone want to write such constructions? What's the advantage? Why instance initialization blocks instead of modifying constructors? What happens when both are used?
# <-------------->
# Thanks for the information! Now I will read comments more often=)
# <-------------->
# I don't understand this statement "The instance initialization block is executed before any constructor of a class...The java compiler invokes the block as the first statement in the constructor, before other statements."
#
# Is the block executed before the constructor or in the constructor as the first statement?
# <-------------->
# Yes, static block is executed before constructor.
# <-------------->
# Then which block, according to the theory is invoked "as the first statement in the constructor, before other statements."?
# <-------------->
# Code in static or initialization blocks are invoked first.
# When you create object, constructor invokes first:
# static {
#    //code
# }
#
# second:
#
# {
#    //code
# }
#
# third: code in constructor
# <-------------->
# Code in static or initialization blocks are executed first.
# When you create object, your code will be executed in this order:
#
# static {
#    //code
# }
#
# {
#    //code
# }
#
# code in constructor
#
# Your question was "Is the block executed before the constructor or in the constructor as the first statement?"
#
# Answer is, when you create object by using keyword "new" you invoke constructor of the class, then code in initialization blocs are executed, then code in constructor is executed.
# <-------------->
#
# ########################################634.0################################
# I think should be noted that filter() returns instance of 'filter' class and when we work with it in fact we interact with values from original iterable object. Thus, if we change some filtered value in original iterable object, this value will be changed in filter instance also.
# <-------------->
# That is indeed incredibly important to know. thank you for saving me from running into a bug!
# <-------------->
# typo in Conclusions, last point, "they can *be*" not me :P
# <-------------->
# What does 'iterator is returned' means?
# <-------------->
# To me personally the last example of paragraph 1 is confusing:
# x_list = [1, 2, 3]
# y_list = [4, 5, 6]
# z_list = [7, 8, 9]
# s = list(map(lambda x, y, z: x + y + z, x_list, y_list, z_list))
# print(s)
# # The output is [12, 15, 18]
#
# My question is: how does lambda "know" what elements to add:
# Option1: x[0] + y[0] + z[0]; or
# Option2: x[0] + x[1] + x[2]
# Thanks.
# <-------------->
# Regrettably there are no examples of at least some conditions where map() and filter() could be faster vs. list comprehensions (and why)
# <-------------->
# Shouldn't this example 'odd_numbers = filter(lambda x: x % 2, numbers)' be 'x % 2 == 0'?
# <-------------->
# example of filter is wrong.
# <-------------->
# No, this is actually correct. The filter is letting pass through only those numbers for which x % 2 evaluates to True, i.e. odd numbers.  The number zero is 'falsey' in Python, therefore even numbers don't get through the filter gate.  The expression might also be rewritten as:
#
# filter(lambda x: x % 2 > 0, numbers)
# <-------------->
# Oh! I see. Thanks for your answer.
# <-------------->
# guys, i dont get the meaning of boolean function in filter( )
# so after your explanation i dont have enough reason to use it. You dont have better examples then odd and even numbers? it's level for dummies
# <-------------->
# I miss the information: when map/filter is faster/better than list comprehensions.
# <-------------->
# The difference between filter and map, when you use map() with a conditional statement it will return or print a list with True or False and when you use a filter() with a conditional statement it will return or print a list with elements.
# <-------------->
# the difference between map() and filter() is that map() doesn't work with conditional statements and if it works it returns or prints a list with True or False like 0 for false and 1 for True, but, if you use filter with function that has a conditional statement it will return a list with elements not a True or false
# <-------------->
# "As you might have already noticed, you can do the same thing in a for loop" Technically, it is a list comprehension, not a for loop. Anyway, according to Fluent Python book, list comprehensions are almost always a faster and more readable solution.
# <-------------->
# "As you might have already noticed, you can do the same thing in a for loop" Technically, it is a list comprehension, not a for loop. In any way, In Python 3, map and filter return generators—a form of iterator—so their direct substitute is now a generator expression and not list comprehension.
# <-------------->
# Isn't 2*x from the examples considered as bad code-styling?
# <-------------->
# "At the same time, under some conditions, map() and filter() can be faster than list comprehensions, so it's definitely worth keeping them in mind." -> What are those conditions ?
# <-------------->
# There's a good stack overflow discussion going on here: https://stackoverflow.com/questions/1247486/list-comprehension-vs-map
# Read the comments under the answers as well, python 3.x users are reporting map()'s performance gains much faster for pre-defined functions.
# Apparently CPython has function call overhead. https://stackoverflow.com/a/22893174 discusses this.
# <-------------->
# Yeah - in old good Python2 map() and filter() were returning lists not expressions.
# Together with reduce() function (removed in Pyton3 :( ) made programming so much simpler than in Python3.
# <-------------->
# perhaps `map(function, iterable)` will look more useful if the example shows that `function` can be multi-line. And also to remind you that list comprehension (as well as `lambda`) should be single-line. The same can be said about `filter(boolean_function, iterable)`
# <-------------->
# Glad this question is asked and then answered. I was also confused.
# <-------------->
# it's cool to rewrite your old code with new obtained knowledge
# <-------------->
#
# ########################################1342.0################################
# The topic should have a stronger emphasis on ssh instead of telnet. Even within a corporate network, it's a bad idea to be using telnet - data is meant to be encrypted so if hackers break in, they can't cause too much damage
# <-------------->
# Absolutely not
# This topic is about availability checking, not remote administration, so ssh isn't of much use
# <-------------->
# Agree, ssh can be object for another whole topic.
# <-------------->
# I think it should be mentioned about the stop command for ping on Mac OS. To stop the ping, after seeing enough results, press Ctrl + C.
# <-------------->
# Ping : " If the reply packet is not received, then the problem isn't with the code but with its connection to the server. "
#
# As some firewalls disable the ping response by default, this assertion is often wrong.
# <-------------->
# This key combination should be applicable for stopping any running commands/applications (started within CLI) in your current terminal session, both in Unix(-like) and Windows systems. This is not ping-specific. And it's not the only possible solution, to get the control back over your CLI.
# <-------------->
# Please, please add a separate section about ssh.
# <-------------->
# As others stated, the server can have ICMP echo requests blocked by firewall to prevent ping of death or smurfing so trusting ping 100% is not a good idea.
# <-------------->
# Bountied? Are you expecting anyone to add a separate SSH section in the comments? :D
# <-------------->

# %% [markdown]
# * 673 -- bad from the previous case
# * 227 -- could use some improvement
# * 166 -- too!
# * 6  -- too
# * 232 -- bad from the previous case
# * 998 -- it's OK
# * 585 -- bad from the previous case
# * 429 -- bad from the previous case
# * 685 -- it's OK
# * 529 -- may need improvement
# * 530 -- may need improvement
# * 121 -- bad from the previous case
# * 634 -- may need improvement
# * 1342 -- it's OK

# %%
topic_id_step_id_mapping = pickle.load(open('topic_id_step_id_mapping.pkl', 'br'))

# %%
step_for_585 = topic_id_step_id_mapping[585]
topic_statistics[topic_statistics.step_id == step_for_585]
# Out:
#       step_id  is_theory                                               text  \
# 1001     7665          1  "<p>You've already learned the theory behind <...
#
#       seconds_to_complete  last_3_month_completion_rate  \
# 1001                570.0                          0.68
#
#       last_3_month_avg_like  last_3_month_completed_step_users_count  \
# 1001                   1.91                                    164.0
#
#       last_3_month_likes_count  last_3_month_topic_completion_rate  \
# 1001                      22.0                                0.81
#
#       last_3_month_completed_topic_users_count  \
# 1001                                     151.0
#
#       back_to_theory_times_per_user_session_avg_last_3_month  \
# 1001                                               0.75
#
#       back_to_theory_users_%_last_3_month  \
# 1001                                44.78
#
#                                           cleaned_texts  num_words  \
# 1001  You've already learned the theory behind recur...       1101
#
#       num_sentences  num_syllables  flesch_score  dale_chall_score
# 1001             57           1671     58.831109          8.782283

# %%
# let's save the version with the threshold 3
df_with_features = pd.DataFrame({'topic_id': list([int(el) for el in final_bad_topics_3]) +\
                                 list([int(el) for el in final_rest_topics_3]), 
                                'target': [1] * len(final_bad_topics_3) + [0] * len(final_rest_topics_3)})

# %%
path = './new_cleaned/train_corpus/target_features'
df_with_features.to_csv(f'{path}/topic_ids_with_target_features_VER3.csv', index=False)
